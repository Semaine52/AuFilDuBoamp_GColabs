# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_03_Typepouvoiradjudicateur_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_03_Typepouvoiradjudicateur BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# Plein écran ► https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_03_typepouvoiradjudicateur.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_03_typepouvoiradjudicateur.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_03_typepouvoiradjudicateur.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_03' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_03' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 17-23813 to 19-184028
# Data columns (total 7 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   D_03_01_Typepouvoiradjudicateur_Minautoritenationale   10 non-null     bool
#  1   D_03_02_Typepouvoiradjudicateur_Agencenational         10 non-null     bool
#  2   D_03_03_Typepouvoiradjudicateur_Autotriteregional      10 non-null     bool
#  3   D_03_04_Typepouvoiradjudicateur_Agenceregional         10 non-null     bool
#  4   D_03_05_Typepouvoiradjudicateur_Orgdroitpublic         10 non-null     bool
#  5   D_03_06_Typepouvoiradjudicateur_Institutioneuropeenne  10 non-null     bool
#  6   D_03_07_Typepouvoiradjudicateur_Autre                  4 non-null      object
# dtypes: bool(6), object(1)
# memory usage: 220.0+ bytes

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                 D_03_01_Typepouvoiradjudicateur_Minautoritenationale  \
# BOAMP_AVIS_NUM
# 17-23813                                                       False
# 19-109490                                                      False
# 19-109992                                                      False
# 19-110063                                                      False
# 19-114272                                                      False
# 21-37182                                                       False
# 19-141762                                                      False
# 19-170952                                                      False
# 19-180078                                                      False
# 19-184028                                                      False
#
#                 D_03_02_Typepouvoiradjudicateur_Agencenational  \
# BOAMP_AVIS_NUM
# 17-23813                                                 False
# 19-109490                                                False
# 19-109992                                                False
# 19-110063                                                False
# 19-114272                                                False
# 21-37182                                                 False
# 19-141762                                                False
# 19-170952                                                False
# 19-180078                                                False
# 19-184028                                                False
#
#                 D_03_03_Typepouvoiradjudicateur_Autotriteregional  \
# BOAMP_AVIS_NUM
# 17-23813                                                    False
# 19-109490                                                    True
# 19-109992                                                   False
# 19-110063                                                    True
# 19-114272                                                   False
# 21-37182                                                    False
# 19-141762                                                   False
# 19-170952                                                    True
# 19-180078                                                   False
# 19-184028                                                   False
#
#                 D_03_04_Typepouvoiradjudicateur_Agenceregional  \
# BOAMP_AVIS_NUM
# 17-23813                                                  True
# 19-109490                                                False
# 19-109992                                                False
# 19-110063                                                False
# 19-114272                                                False
# 21-37182                                                 False
# 19-141762                                                 True
# 19-170952                                                False
# 19-180078                                                False
# 19-184028                                                False
#
#                 D_03_05_Typepouvoiradjudicateur_Orgdroitpublic  \
# BOAMP_AVIS_NUM
# 17-23813                                                 False
# 19-109490                                                False
# 19-109992                                                False
# 19-110063                                                False
# 19-114272                                                 True
# 21-37182                                                 False
# 19-141762                                                False
# 19-170952                                                False
# 19-180078                                                False
# 19-184028                                                False
#
#                 D_03_06_Typepouvoiradjudicateur_Institutioneuropeenne  \
# BOAMP_AVIS_NUM
# 17-23813                                                        False
# 19-109490                                                       False
# 19-109992                                                       False
# 19-110063                                                       False
# 19-114272                                                       False
# 21-37182                                                        False
# 19-141762                                                       False
# 19-170952                                                       False
# 19-180078                                                       False
# 19-184028                                                       False
#
#                              D_03_07_Typepouvoiradjudicateur_Autre
# BOAMP_AVIS_NUM
# 17-23813                                                       NaN
# 19-109490                                                      NaN
# 19-109992                                Collectivité territoriale
# 19-110063                                                      NaN
# 19-114272                                                      NaN
# 21-37182        Etablissement Public de Coopération intercommunale
# 19-141762                                                      NaN
# 19-170952                                                      NaN
# 19-180078                                Collectivité Territoriale
# 19-184028                                  Société publique locale

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
