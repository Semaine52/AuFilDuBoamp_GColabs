# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_07_Publicationanterieure_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_07_Publicationanterieure  BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_07_publicationanterieure.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_07_publicationanterieure.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_07_publicationanterieure.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_07' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_07' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 19-109490 to 20-106965
# Data columns (total 21 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   D_07_01_Publicationanterieure_Oui                                                                                10 non-null     bool
#  1   D_07_02_Publicationanterieure_Referencepublication                                                               10 non-null     object
#  2   D_07_02_01_Publicationanterieure_Referencepublication_Publicationpapier                                          9 non-null      object
#  3   D_07_02_02_Publicationanterieure_Referencepublication_Publicationelectronique                                    0 non-null      float64
#  4   D_07_02_03_Publicationanterieure_Referencepublication_Publicationjoue                                            10 non-null     object
#  5   D_07_02_03_01_Publicationanterieure_Referencepublication_Publicationjoue_Nature                                  10 non-null     object
#  6   D_07_02_03_01_01_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avispreinformation            10 non-null     bool
#  7   D_07_02_03_01_02_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisperiodique                10 non-null     bool
#  8   D_07_02_03_01_03_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avissystemqualif              0 non-null      float64
#  9   D_07_02_03_01_04_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisprofilacheteur            10 non-null     bool
#  10  D_07_02_03_01_05_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisexantevolontaire          10 non-null     bool
#  11  D_07_02_03_01_06_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avismarche                    10 non-null     bool
#  12  D_07_02_03_01_07_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avissad                       0 non-null      float64
#  13  D_07_02_03_01_08_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisconcours                  0 non-null      float64
#  14  D_07_02_03_01_09_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisattribution               10 non-null     bool
#  15  D_07_02_03_01_10_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Autrespublcationsanterieures  10 non-null     bool
#  16  D_07_02_03_02_Publicationanterieure_Referencepublication_Publicationjoue_Annee                                   9 non-null      float64
#  17  D_07_02_03_03_Publicationanterieure_Referencepublication_Publicationjoue_Numparution                             9 non-null      float64
#  18  D_07_02_03_04_Publicationanterieure_Referencepublication_Publicationjoue_Numannonce                              9 non-null      float64
#  19  D_07_02_03_05_Publicationanterieure_Referencepublication_Publicationjoue_Datepublication                         9 non-null      object
#  20  D_07_03_Publicationanterieure_Non                                                                                10 non-null     bool
# dtypes: bool(9), float64(7), object(5)
# memory usage: 1.1+ KB

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                 D_07_01_Publicationanterieure_Oui  \
# BOAMP_AVIS_NUM
# 19-109490                                    True
# 19-109992                                    True
# 19-110063                                    True
# 19-114272                                    True
# 19-124811                                   False
# 21-37182                                     True
# 19-140862                                    True
# 19-184028                                    True
# 20-105182                                    True
# 20-106965                                    True
#
#                D_07_02_Publicationanterieure_Referencepublication  \
# BOAMP_AVIS_NUM
# 19-109490                                             CF_NIV_SUIV
# 19-109992                                             CF_NIV_SUIV
# 19-110063                                             CF_NIV_SUIV
# 19-114272                                             CF_NIV_SUIV
# 19-124811                                             CF_NIV_SUIV
# 21-37182                                              CF_NIV_SUIV
# 19-140862                                             CF_NIV_SUIV
# 19-184028                                             CF_NIV_SUIV
# 20-105182                                             CF_NIV_SUIV
# 20-106965                                             CF_NIV_SUIV
#
#                D_07_02_01_Publicationanterieure_Referencepublication_Publicationpapier  \
# BOAMP_AVIS_NUM
# 19-109490                                                                           []
# 19-109992                                                                           []
# 19-110063                                                                           []
# 19-114272                                                                           []
# 19-124811                                                                          NaN
# 21-37182                                                                            []
# 19-140862                                                                           []
# 19-184028                                                                           []
# 20-105182                                                                           []
# 20-106965                                                                           []
#
#                 D_07_02_02_Publicationanterieure_Referencepublication_Publicationelectronique  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                 NaN
# 19-109992                                                                                 NaN
# 19-110063                                                                                 NaN
# 19-114272                                                                                 NaN
# 19-124811                                                                                 NaN
# 21-37182                                                                                  NaN
# 19-140862                                                                                 NaN
# 19-184028                                                                                 NaN
# 20-105182                                                                                 NaN
# 20-106965                                                                                 NaN
#
#                D_07_02_03_Publicationanterieure_Referencepublication_Publicationjoue  \
# BOAMP_AVIS_NUM
# 19-109490                                                                CF_NIV_SUIV
# 19-109992                                                                CF_NIV_SUIV
# 19-110063                                                                CF_NIV_SUIV
# 19-114272                                                                CF_NIV_SUIV
# 19-124811                                                                CF_NIV_SUIV
# 21-37182                                                                 CF_NIV_SUIV
# 19-140862                                                                CF_NIV_SUIV
# 19-184028                                                                CF_NIV_SUIV
# 20-105182                                                                CF_NIV_SUIV
# 20-106965                                                                CF_NIV_SUIV
#
#                D_07_02_03_01_Publicationanterieure_Referencepublication_Publicationjoue_Nature  \
# BOAMP_AVIS_NUM
# 19-109490                                                                          CF_NIV_SUIV
# 19-109992                                                                          CF_NIV_SUIV
# 19-110063                                                                          CF_NIV_SUIV
# 19-114272                                                                          CF_NIV_SUIV
# 19-124811                                                                          CF_NIV_SUIV
# 21-37182                                                                           CF_NIV_SUIV
# 19-140862                                                                          CF_NIV_SUIV
# 19-184028                                                                          CF_NIV_SUIV
# 20-105182                                                                          CF_NIV_SUIV
# 20-106965                                                                          CF_NIV_SUIV
#
#                 D_07_02_03_01_01_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avispreinformation  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                       False
# 19-109992                                                                                                       False
# 19-110063                                                                                                       False
# 19-114272                                                                                                       False
# 19-124811                                                                                                       False
# 21-37182                                                                                                        False
# 19-140862                                                                                                       False
# 19-184028                                                                                                       False
# 20-105182                                                                                                       False
# 20-106965                                                                                                       False
#
#                 D_07_02_03_01_02_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisperiodique  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                   False
# 19-109992                                                                                                   False
# 19-110063                                                                                                   False
# 19-114272                                                                                                   False
# 19-124811                                                                                                   False
# 21-37182                                                                                                    False
# 19-140862                                                                                                   False
# 19-184028                                                                                                   False
# 20-105182                                                                                                   False
# 20-106965                                                                                                   False
#
#                 D_07_02_03_01_03_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avissystemqualif  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                       NaN
# 19-109992                                                                                                       NaN
# 19-110063                                                                                                       NaN
# 19-114272                                                                                                       NaN
# 19-124811                                                                                                       NaN
# 21-37182                                                                                                        NaN
# 19-140862                                                                                                       NaN
# 19-184028                                                                                                       NaN
# 20-105182                                                                                                       NaN
# 20-106965                                                                                                       NaN
#
#                 D_07_02_03_01_04_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisprofilacheteur  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                       False
# 19-109992                                                                                                       False
# 19-110063                                                                                                       False
# 19-114272                                                                                                       False
# 19-124811                                                                                                       False
# 21-37182                                                                                                        False
# 19-140862                                                                                                       False
# 19-184028                                                                                                       False
# 20-105182                                                                                                       False
# 20-106965                                                                                                       False
#
#                 D_07_02_03_01_05_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisexantevolontaire  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                         False
# 19-109992                                                                                                         False
# 19-110063                                                                                                         False
# 19-114272                                                                                                         False
# 19-124811                                                                                                         False
# 21-37182                                                                                                          False
# 19-140862                                                                                                         False
# 19-184028                                                                                                         False
# 20-105182                                                                                                         False
# 20-106965                                                                                                         False
#
#                 D_07_02_03_01_06_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avismarche  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                True
# 19-109992                                                                                                True
# 19-110063                                                                                                True
# 19-114272                                                                                                True
# 19-124811                                                                                               False
# 21-37182                                                                                                 True
# 19-140862                                                                                               False
# 19-184028                                                                                                True
# 20-105182                                                                                                True
# 20-106965                                                                                                True
#
#                 D_07_02_03_01_07_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avissad  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                              NaN
# 19-109992                                                                                              NaN
# 19-110063                                                                                              NaN
# 19-114272                                                                                              NaN
# 19-124811                                                                                              NaN
# 21-37182                                                                                               NaN
# 19-140862                                                                                              NaN
# 19-184028                                                                                              NaN
# 20-105182                                                                                              NaN
# 20-106965                                                                                              NaN
#
#                 D_07_02_03_01_08_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisconcours  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                   NaN
# 19-109992                                                                                                   NaN
# 19-110063                                                                                                   NaN
# 19-114272                                                                                                   NaN
# 19-124811                                                                                                   NaN
# 21-37182                                                                                                    NaN
# 19-140862                                                                                                   NaN
# 19-184028                                                                                                   NaN
# 20-105182                                                                                                   NaN
# 20-106965                                                                                                   NaN
#
#                 D_07_02_03_01_09_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Avisattribution  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                    False
# 19-109992                                                                                                    False
# 19-110063                                                                                                    False
# 19-114272                                                                                                    False
# 19-124811                                                                                                    False
# 21-37182                                                                                                     False
# 19-140862                                                                                                     True
# 19-184028                                                                                                    False
# 20-105182                                                                                                    False
# 20-106965                                                                                                    False
#
#                 D_07_02_03_01_10_Publicationanterieure_Referencepublication_Publicationjoue_Nature_Autrespublcationsanterieures  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                                                 False
# 19-109992                                                                                                                 False
# 19-110063                                                                                                                 False
# 19-114272                                                                                                                 False
# 19-124811                                                                                                                 False
# 21-37182                                                                                                                  False
# 19-140862                                                                                                                 False
# 19-184028                                                                                                                 False
# 20-105182                                                                                                                 False
# 20-106965                                                                                                                 False
#
#                 D_07_02_03_02_Publicationanterieure_Referencepublication_Publicationjoue_Annee  \
# BOAMP_AVIS_NUM
# 19-109490                                                                               2019.0
# 19-109992                                                                               2018.0
# 19-110063                                                                               2019.0
# 19-114272                                                                               2019.0
# 19-124811                                                                                  NaN
# 21-37182                                                                                2020.0
# 19-140862                                                                               2018.0
# 19-184028                                                                               2018.0
# 20-105182                                                                               2020.0
# 20-106965                                                                               2020.0
#
#                 D_07_02_03_03_Publicationanterieure_Referencepublication_Publicationjoue_Numparution  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                      105.0
# 19-109992                                                                                      150.0
# 19-110063                                                                                       73.0
# 19-114272                                                                                       23.0
# 19-124811                                                                                        NaN
# 21-37182                                                                                       120.0
# 19-140862                                                                                      135.0
# 19-184028                                                                                      217.0
# 20-105182                                                                                      136.0
# 20-106965                                                                                       74.0
#
#                 D_07_02_03_04_Publicationanterieure_Referencepublication_Publicationjoue_Numannonce  \
# BOAMP_AVIS_NUM
# 19-109490                                                                                  255203.0
# 19-109992                                                                                  343481.0
# 19-110063                                                                                  173579.0
# 19-114272                                                                                   50499.0
# 19-124811                                                                                       NaN
# 21-37182                                                                                   291614.0
# 19-140862                                                                                  309451.0
# 19-184028                                                                                  496597.0
# 20-105182                                                                                  333848.0
# 20-106965                                                                                  175894.0
#
#                D_07_02_03_05_Publicationanterieure_Referencepublication_Publicationjoue_Datepublication  \
# BOAMP_AVIS_NUM
# 19-109490                                                                           2019-06-02 22:00:00
# 19-109992                                                                           2018-08-06 22:00:00
# 19-110063                                                                           2019-04-11 22:00:00
# 19-114272                                                                           2019-01-31 23:00:00
# 19-124811                                                                                           NaN
# 21-37182                                                                            2020-06-23 22:00:00
# 19-140862                                                                           2018-07-16 22:00:00
# 19-184028                                                                           2018-11-09 23:00:00
# 20-105182                                                                           2020-07-15 22:00:00
# 20-106965                                                                           2020-04-14 22:00:00
#
#                 D_07_03_Publicationanterieure_Non
# BOAMP_AVIS_NUM
# 19-109490                                   False
# 19-109992                                   False
# 19-110063                                   False
# 19-114272                                   False
# 19-124811                                    True
# 21-37182                                    False
# 19-140862                                   False
# 19-184028                                   False
# 20-105182                                   False
# 20-106965                                   False

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
