# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_12_Conditionrelativemarche_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_12_Conditionrelativemarche BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_12_conditionrelativemarche.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_12_conditionrelativemarche.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_12_conditionrelativemarche.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_12' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_12' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 17-23813 to 19-180078
# Data columns (total 12 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   D_12_01_Conditionrelativemarche_Cautionnement                 3 non-null      object
#  1   D_12_02_Conditionrelativemarche_Financement                   4 non-null      object
#  2   D_12_03_Conditionrelativemarche_Formejuridique                3 non-null      object
#  3   D_12_04_Conditionrelativemarche_Participationelectroniqueoui  10 non-null     bool
#  4   D_12_05_Conditionrelativemarche_Participationelectroniquenon  10 non-null     bool
#  5   D_12_06_Conditionrelativemarche_Autresconditionspartoui       0 non-null      object
#  6   D_12_07_Conditionrelativemarche_Autresconditionspartnon       10 non-null     bool
#  7   D_12_08_Conditionrelativemarche_Unitemonetaireeur             10 non-null     bool
#  8   D_12_09_Conditionrelativemarche_Francaisseul                  10 non-null     bool
#  9   D_12_10_Conditionrelativemarche_Langues                       10 non-null     object
#  10  D_12_10_01_Conditionrelativemarche_Langues_Langue             7 non-null      object
#  11  D_12_10_02_Conditionrelativemarche_Langues_Autres             0 non-null      object
# dtypes: bool(5), object(7)
# memory usage: 690.0+ bytes

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                                                                                                              D_12_01_Conditionrelativemarche_Cautionnement  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                                               NaN
# 18-78695                                                                                                                                               NaN
# 19-102527                                                                                                                                              NaN
# 19-110914                                                             Voir cahier des clauses administratives particulières (CCAP) no19A90019, article 10.
# 19-119912                                                                                                  il ne sera pas appliqué de retenue de garantie.
# 11-116542       Aucune clause de garantie financière ne sera appliquée sauf dans le cas d'une demande d'avance.Le montant de l'avance sera garanti à 100%.
# 19-141762                                                                                                                                              NaN
# 19-170952                                                                                                                                              NaN
# 19-174419                                                                                                                                              NaN
# 19-180078                                                                                                                                              NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                D_12_02_Conditionrelativemarche_Financement  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 18-78695        Le délai global de paiement est de 30 jours. Sous réserve d'une part que le montant initial du marché soit supérieur à 50 000 euro hors taxe et dans la mesure où le délai d'exécution est supérieur à deux mois ; et d'autre part si le titulaire a exprimé son accord pour bénéficier d'une avance dans l'acte d'engagement ;une avance est accordée au titulaire du marché dans les conditions suivantes :-pour le lot no 1 : Bardage isolation, le pourcentage de l'avance accordé est de : 15%-pour les autres lots, le pourcentage de l'avance accordé est de : 10 %
# 19-102527                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 19-110914                                                                                                                                                                                                                                                                                                                                                                                  Ressources propres : budget du ministère des arméesDélai de paiement sous 30 jours maximum (Voir article 15 du CCAP)Mode de règlement : virement administratifAvances : voir article 12 du CCAP
# 19-119912                                                                                                                                                                                                                                                                                                                                                                      financement prévisionnel constitué par les ressources propres du SDIS de l'isère. Le règlement des dépenses se fera par mandat administratif suivi d'un virement bancaire. Le délai de paiement : 30 jours.
# 11-116542                                                                                                                                                                                                                                                                                                                                                                                       Les règles de la comptabilité publique s'appliquent. Le délai global de paiement est de 30 jours à compter de la date de réception de la facture ou de la demande de paiement équivalente.
# 19-141762                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 19-170952                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 19-174419                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 19-180078                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#
#                         D_12_03_Conditionrelativemarche_Formejuridique  \
# BOAMP_AVIS_NUM
# 17-23813                                                           NaN
# 18-78695                                                           NaN
# 19-102527                                                          NaN
# 19-110914           Voir Art. 12 du règlement de la consultation (RC).
# 19-119912             solidaire ou conjoint avec mandataire solidaire.
# 11-116542       Aucune forme de groupement n'est imposé aux candidats.
# 19-141762                                                          NaN
# 19-170952                                                          NaN
# 19-174419                                                          NaN
# 19-180078                                                          NaN
#
#                 D_12_04_Conditionrelativemarche_Participationelectroniqueoui  \
# BOAMP_AVIS_NUM
# 17-23813                                                                True
# 18-78695                                                               False
# 19-102527                                                              False
# 19-110914                                                              False
# 19-119912                                                              False
# 11-116542                                                              False
# 19-141762                                                               True
# 19-170952                                                              False
# 19-174419                                                              False
# 19-180078                                                               True
#
#                 D_12_05_Conditionrelativemarche_Participationelectroniquenon  \
# BOAMP_AVIS_NUM
# 17-23813                                                               False
# 18-78695                                                               False
# 19-102527                                                              False
# 19-110914                                                              False
# 19-119912                                                              False
# 11-116542                                                              False
# 19-141762                                                              False
# 19-170952                                                               True
# 19-174419                                                              False
# 19-180078                                                              False
#
#                D_12_06_Conditionrelativemarche_Autresconditionspartoui  \
# BOAMP_AVIS_NUM
# 17-23813                                                           NaN
# 18-78695                                                           NaN
# 19-102527                                                          NaN
# 19-110914                                                          NaN
# 19-119912                                                          NaN
# 11-116542                                                          NaN
# 19-141762                                                          NaN
# 19-170952                                                          NaN
# 19-174419                                                          NaN
# 19-180078                                                          NaN
#
#                 D_12_07_Conditionrelativemarche_Autresconditionspartnon  \
# BOAMP_AVIS_NUM
# 17-23813                                                          False
# 18-78695                                                           True
# 19-102527                                                         False
# 19-110914                                                         False
# 19-119912                                                         False
# 11-116542                                                          True
# 19-141762                                                          True
# 19-170952                                                         False
# 19-174419                                                         False
# 19-180078                                                          True
#
#                 D_12_08_Conditionrelativemarche_Unitemonetaireeur  \
# BOAMP_AVIS_NUM
# 17-23813                                                    False
# 18-78695                                                     True
# 19-102527                                                    True
# 19-110914                                                   False
# 19-119912                                                    True
# 11-116542                                                    True
# 19-141762                                                   False
# 19-170952                                                   False
# 19-174419                                                    True
# 19-180078                                                   False
#
#                 D_12_09_Conditionrelativemarche_Francaisseul  \
# BOAMP_AVIS_NUM
# 17-23813                                               False
# 18-78695                                               False
# 19-102527                                               True
# 19-110914                                              False
# 19-119912                                               True
# 11-116542                                              False
# 19-141762                                              False
# 19-170952                                              False
# 19-174419                                              False
# 19-180078                                              False
#
#                D_12_10_Conditionrelativemarche_Langues  \
# BOAMP_AVIS_NUM
# 17-23813                                   CF_NIV_SUIV
# 18-78695                                   CF_NIV_SUIV
# 19-102527                                  CF_NIV_SUIV
# 19-110914                                  CF_NIV_SUIV
# 19-119912                                  CF_NIV_SUIV
# 11-116542                                  CF_NIV_SUIV
# 19-141762                                  CF_NIV_SUIV
# 19-170952                                  CF_NIV_SUIV
# 19-174419                                  CF_NIV_SUIV
# 19-180078                                  CF_NIV_SUIV
#
#                D_12_10_01_Conditionrelativemarche_Langues_Langue  \
# BOAMP_AVIS_NUM
# 17-23813                                                  ['FR']
# 18-78695                                                  ['FR']
# 19-102527                                                    NaN
# 19-110914                                                 ['FR']
# 19-119912                                                    NaN
# 11-116542                                                    NaN
# 19-141762                                                 ['FR']
# 19-170952                                                 ['FR']
# 19-174419                                                 ['FR']
# 19-180078                                                 ['FR']
#
#                D_12_10_02_Conditionrelativemarche_Langues_Autres
# BOAMP_AVIS_NUM
# 17-23813                                                     NaN
# 18-78695                                                     NaN
# 19-102527                                                    NaN
# 19-110914                                                    NaN
# 19-119912                                                    NaN
# 11-116542                                                    NaN
# 19-141762                                                    NaN
# 19-170952                                                    NaN
# 19-174419                                                    NaN
# 19-180078                                                    NaN

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
