# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_11_Conditiondelai_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_11_Conditiondelai BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_11_conditiondelai.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_11_conditiondelai.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_11_conditiondelai.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_11' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_11' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 07-127994 to 19-180078
# Data columns (total 8 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   D_11_01_Conditiondelai_Receptcandidat              0 non-null      object
#  1   D_11_02_Conditiondelai_Receptoffres                10 non-null     object
#  2   D_11_03_Conditiondelai_Limiteenvoiinvit            0 non-null      object
#  3   D_11_04_Conditiondelai_Validiteoffre               10 non-null     object
#  4   D_11_04_01_Conditiondelai_Validiteoffre_Jusquau    0 non-null      float64
#  5   D_11_04_02_Conditiondelai_Validiteoffre_Dureemois  3 non-null      float64
#  6   D_11_04_03_Conditiondelai_Validiteoffre_Dureejour  3 non-null      float64
#  7   D_11_05_Conditiondelai_Dureesystemequalification   0 non-null      float64
# dtypes: float64(4), object(4)
# memory usage: 720.0+ bytes

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                D_11_01_Conditiondelai_Receptcandidat  \
# BOAMP_AVIS_NUM
# 07-127994                                        NaN
# 17-23813                                         NaN
# 17-31705                                         NaN
# 18-55590                                         NaN
# 18-78695                                         NaN
# 11-116542                                        NaN
# 19-141762                                        NaN
# 19-170952                                        NaN
# 19-174419                                        NaN
# 19-180078                                        NaN
#
#                D_11_02_Conditiondelai_Receptoffres  \
# BOAMP_AVIS_NUM
# 07-127994                      2020-02-20 11:00:00
# 17-23813                       2020-03-18 11:00:00
# 17-31705                       2020-03-02 10:00:00
# 18-55590                       2020-02-18 16:00:00
# 18-78695                       2020-03-09 10:00:00
# 11-116542                      2021-02-08 11:00:00
# 19-141762                      2021-02-12 11:15:00
# 19-170952                      2021-02-17 11:00:00
# 19-174419                      2021-02-10 11:00:00
# 19-180078                      2021-02-23 11:00:00
#
#                D_11_03_Conditiondelai_Limiteenvoiinvit  \
# BOAMP_AVIS_NUM
# 07-127994                                          NaN
# 17-23813                                           NaN
# 17-31705                                           NaN
# 18-55590                                           NaN
# 18-78695                                           NaN
# 11-116542                                          NaN
# 19-141762                                          NaN
# 19-170952                                          NaN
# 19-174419                                          NaN
# 19-180078                                          NaN
#
#                D_11_04_Conditiondelai_Validiteoffre  \
# BOAMP_AVIS_NUM
# 07-127994                               CF_NIV_SUIV
# 17-23813                                CF_NIV_SUIV
# 17-31705                                CF_NIV_SUIV
# 18-55590                                CF_NIV_SUIV
# 18-78695                                CF_NIV_SUIV
# 11-116542                               CF_NIV_SUIV
# 19-141762                               CF_NIV_SUIV
# 19-170952                               CF_NIV_SUIV
# 19-174419                               CF_NIV_SUIV
# 19-180078                               CF_NIV_SUIV
#
#                 D_11_04_01_Conditiondelai_Validiteoffre_Jusquau  \
# BOAMP_AVIS_NUM
# 07-127994                                                   NaN
# 17-23813                                                    NaN
# 17-31705                                                    NaN
# 18-55590                                                    NaN
# 18-78695                                                    NaN
# 11-116542                                                   NaN
# 19-141762                                                   NaN
# 19-170952                                                   NaN
# 19-174419                                                   NaN
# 19-180078                                                   NaN
#
#                 D_11_04_02_Conditiondelai_Validiteoffre_Dureemois  \
# BOAMP_AVIS_NUM
# 07-127994                                                     NaN
# 17-23813                                                      NaN
# 17-31705                                                      NaN
# 18-55590                                                      NaN
# 18-78695                                                      5.0
# 11-116542                                                     NaN
# 19-141762                                                     4.0
# 19-170952                                                     NaN
# 19-174419                                                     NaN
# 19-180078                                                     3.0
#
#                 D_11_04_03_Conditiondelai_Validiteoffre_Dureejour  \
# BOAMP_AVIS_NUM
# 07-127994                                                    90.0
# 17-23813                                                      NaN
# 17-31705                                                      NaN
# 18-55590                                                      NaN
# 18-78695                                                      NaN
# 11-116542                                                   120.0
# 19-141762                                                     NaN
# 19-170952                                                     NaN
# 19-174419                                                   120.0
# 19-180078                                                     NaN
#
#                 D_11_05_Conditiondelai_Dureesystemequalification
# BOAMP_AVIS_NUM
# 07-127994                                                    NaN
# 17-23813                                                     NaN
# 17-31705                                                     NaN
# 18-55590                                                     NaN
# 18-78695                                                     NaN
# 11-116542                                                    NaN
# 19-141762                                                    NaN
# 19-170952                                                    NaN
# 19-174419                                                    NaN
# 19-180078                                                    NaN

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
