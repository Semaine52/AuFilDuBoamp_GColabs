# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_20_Annexed3_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_20_Annexed3  BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_20_annexed3.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_20_annexed3.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_20_annexed3.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_20' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_20' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 20-51973 to 21-59776
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   D_20_01_Annexed3_Infructueuxrestreinte     0 non-null      object
#  1   D_20_02_Annexed3_Infructueuxdialogue       0 non-null      object
#  2   D_20_03_Annexed3_Infructueuxnegocieesspub  0 non-null      object
#  3   D_20_04_Annexed3_Autreservice              0 non-null      object
#  4   D_20_05_Annexed3_Recherche                 0 non-null      object
#  5   D_20_06_Annexed3_Offresirregulieres        0 non-null      object
#  6   D_20_07_Annexed3_Raisonstechniques         0 non-null      object
#  7   D_20_08_Annexed3_Proprieteintellectuelle   0 non-null      object
#  8   D_20_09_Annexed3_Delaisincompatibles       0 non-null      object
#  9   D_20_10_Annexed3_Urgenceimperieuse         0 non-null      object
#  10  D_20_11_Annexed3_Marchecomplementaire      0 non-null      object
#  11  D_20_12_Annexed3_Prestationsidentiques     0 non-null      object
#  12  D_20_13_Annexed3_Matierespremieres         0 non-null      object
#  13  D_20_14_Annexed3_Cessationactivite         0 non-null      object
#  14  D_20_15_Annexed3_Liquidateurs              0 non-null      object
#  15  D_20_16_Annexed3_Servicemartime            0 non-null      object
#  16  D_20_17_Annexed3_Horsscope                 3 non-null      object
#  17  D_20_18_Annexed3_Serviceslistes            0 non-null      object
#  18  D_20_19_Annexed3_Explication               3 non-null      object
# dtypes: object(19)
# memory usage: 480.0+ bytes

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                D_20_01_Annexed3_Infructueuxrestreinte  \
# BOAMP_AVIS_NUM
# 20-51973                                          NaN
# 21-45514                                          NaN
# 21-59776                                          NaN
#
#                D_20_02_Annexed3_Infructueuxdialogue  \
# BOAMP_AVIS_NUM
# 20-51973                                        NaN
# 21-45514                                        NaN
# 21-59776                                        NaN
#
#                D_20_03_Annexed3_Infructueuxnegocieesspub  \
# BOAMP_AVIS_NUM
# 20-51973                                             NaN
# 21-45514                                             NaN
# 21-59776                                             NaN
#
#                D_20_04_Annexed3_Autreservice D_20_05_Annexed3_Recherche  \
# BOAMP_AVIS_NUM
# 20-51973                                 NaN                        NaN
# 21-45514                                 NaN                        NaN
# 21-59776                                 NaN                        NaN
#
#                D_20_06_Annexed3_Offresirregulieres  \
# BOAMP_AVIS_NUM
# 20-51973                                       NaN
# 21-45514                                       NaN
# 21-59776                                       NaN
#
#                D_20_07_Annexed3_Raisonstechniques  \
# BOAMP_AVIS_NUM
# 20-51973                                      NaN
# 21-45514                                      NaN
# 21-59776                                      NaN
#
#                D_20_08_Annexed3_Proprieteintellectuelle  \
# BOAMP_AVIS_NUM
# 20-51973                                            NaN
# 21-45514                                            NaN
# 21-59776                                            NaN
#
#                D_20_09_Annexed3_Delaisincompatibles  \
# BOAMP_AVIS_NUM
# 20-51973                                        NaN
# 21-45514                                        NaN
# 21-59776                                        NaN
#
#                D_20_10_Annexed3_Urgenceimperieuse  \
# BOAMP_AVIS_NUM
# 20-51973                                      NaN
# 21-45514                                      NaN
# 21-59776                                      NaN
#
#                D_20_11_Annexed3_Marchecomplementaire  \
# BOAMP_AVIS_NUM
# 20-51973                                         NaN
# 21-45514                                         NaN
# 21-59776                                         NaN
#
#                D_20_12_Annexed3_Prestationsidentiques  \
# BOAMP_AVIS_NUM
# 20-51973                                          NaN
# 21-45514                                          NaN
# 21-59776                                          NaN
#
#                D_20_13_Annexed3_Matierespremieres  \
# BOAMP_AVIS_NUM
# 20-51973                                      NaN
# 21-45514                                      NaN
# 21-59776                                      NaN
#
#                D_20_14_Annexed3_Cessationactivite  \
# BOAMP_AVIS_NUM
# 20-51973                                      NaN
# 21-45514                                      NaN
# 21-59776                                      NaN
#
#                D_20_15_Annexed3_Liquidateurs D_20_16_Annexed3_Servicemartime  \
# BOAMP_AVIS_NUM
# 20-51973                                 NaN                             NaN
# 21-45514                                 NaN                             NaN
# 21-59776                                 NaN                             NaN
#
#                                                                                                   D_20_17_Annexed3_Horsscope  \
# BOAMP_AVIS_NUM
# 20-51973        <?xml version="1.0" encoding="UTF-16"?>\n<HORS_SCOPE xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 21-45514        <?xml version="1.0" encoding="UTF-16"?>\n<HORS_SCOPE xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 21-59776        <?xml version="1.0" encoding="UTF-16"?>\n<HORS_SCOPE xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
#
#                D_20_18_Annexed3_Serviceslistes  \
# BOAMP_AVIS_NUM
# 20-51973                                   NaN
# 21-45514                                   NaN
# 21-59776                                   NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              D_20_19_Annexed3_Explication
# BOAMP_AVIS_NUM
# 20-51973                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Marché passé selon la procédure adaptée des articles L. 2123-1 et R. 2123-1 du code de la commande publique</EXPLICATION>
# 21-45514        <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Considérant que les marchés peuvent être sans publicité ni mise en concurrence préalables, lorsque les travaux, fournitures ou services ne peuvent être fournis que par un opérateur économique déterminé, pour lune des raisons suivantes : a) Le marché public a pour objet la création ou lacquisition dune uvre dart ou dune performance artistique unique ; b) Des raisons techniques; c) La protection de droits dexclusivité, notamment de droits de propriété intellectuelle. Considérant queu égard à son exposition médiatique, seule la SASP USAP peut fournir à la Ville ces prestations de communications.</EXPLICATION>
# 21-59776                                                                                                                                                                                                                                                                                   <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">En vertu des directives 2014/24/UE du Parlement européen et du Conseil du 26 février 2014, le montant du présent accord-cadre mono-attributaire à bons de commande de service est inférieur au seuil d'application des directives susvisées. Ce dernier n'est donc pas soumis à l'obligation de publication préalable d'un avis de publicité au JOUE</EXPLICATION>

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
