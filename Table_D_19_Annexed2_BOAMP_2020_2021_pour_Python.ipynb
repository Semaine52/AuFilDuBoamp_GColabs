# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_19_Annexed2_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_19_Annexed2 BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_19_annexed2.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_19_annexed2.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_19_annexed2.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_19' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_19' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 20-186 to 21-8976
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   D_19_01_Annexed2_Infructueux              0 non-null      object
#  1   D_19_02_Annexed2_Recherche                1 non-null      object
#  2   D_19_03_Annexed2_Raisonstechniques        10 non-null     object
#  3   D_19_04_Annexed2_Raisonsartistiques       0 non-null      object
#  4   D_19_05_Annexed2_Proprieteintellectuelle  10 non-null     object
#  5   D_19_06_Annexed2_Urgenceimperieuse        0 non-null      object
#  6   D_19_07_Annexed2_Marchecomplementaire     0 non-null      object
#  7   D_19_08_Annexed2_Prestationsidentiques    0 non-null      object
#  8   D_19_09_Annexed2_Laureatsconcours         0 non-null      object
#  9   D_19_10_Annexed2_Matierespremieres        0 non-null      object
#  10  D_19_11_Annexed2_Cessationactivite        0 non-null      object
#  11  D_19_12_Annexed2_Liquidateurs             0 non-null      object
#  12  D_19_13_Annexed2_Achatopportunite         0 non-null      object
#  13  D_19_14_Annexed2_Horsscope                10 non-null     object
#  14  D_19_15_Annexed2_Explication              10 non-null     object
# dtypes: object(15)
# memory usage: 1.2+ KB

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                D_19_01_Annexed2_Infructueux  \
# BOAMP_AVIS_NUM
# 20-186                                  NaN
# 20-8603                                 NaN
# 20-8635                                 NaN
# 20-9196                                 NaN
# 20-9689                                 NaN
# 21-13108                                NaN
# 21-13154                                NaN
# 21-4265                                 NaN
# 21-4817                                 NaN
# 21-8976                                 NaN
#
#                                                                                                  D_19_02_Annexed2_Recherche  \
# BOAMP_AVIS_NUM
# 20-186                                                                                                                  NaN
# 20-8603                                                                                                                 NaN
# 20-8635         <?xml version="1.0" encoding="UTF-16"?>\n<RECHERCHE xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 20-9196                                                                                                                 NaN
# 20-9689                                                                                                                 NaN
# 21-13108                                                                                                                NaN
# 21-13154                                                                                                                NaN
# 21-4265                                                                                                                 NaN
# 21-4817                                                                                                                 NaN
# 21-8976                                                                                                                 NaN
#
#                D_19_03_Annexed2_Raisonstechniques  \
# BOAMP_AVIS_NUM
# 20-186                                       True
# 20-8603                                      True
# 20-8635                                     False
# 20-9196                                     False
# 20-9689                                     False
# 21-13108                                    False
# 21-13154                                     True
# 21-4265                                      True
# 21-4817                                      True
# 21-8976                                     False
#
#                D_19_04_Annexed2_Raisonsartistiques  \
# BOAMP_AVIS_NUM
# 20-186                                         NaN
# 20-8603                                        NaN
# 20-8635                                        NaN
# 20-9196                                        NaN
# 20-9689                                        NaN
# 21-13108                                       NaN
# 21-13154                                       NaN
# 21-4265                                        NaN
# 21-4817                                        NaN
# 21-8976                                        NaN
#
#                D_19_05_Annexed2_Proprieteintellectuelle  \
# BOAMP_AVIS_NUM
# 20-186                                            False
# 20-8603                                           False
# 20-8635                                           False
# 20-9196                                            True
# 20-9689                                           False
# 21-13108                                          False
# 21-13154                                          False
# 21-4265                                           False
# 21-4817                                           False
# 21-8976                                            True
#
#                D_19_06_Annexed2_Urgenceimperieuse  \
# BOAMP_AVIS_NUM
# 20-186                                        NaN
# 20-8603                                       NaN
# 20-8635                                       NaN
# 20-9196                                       NaN
# 20-9689                                       NaN
# 21-13108                                      NaN
# 21-13154                                      NaN
# 21-4265                                       NaN
# 21-4817                                       NaN
# 21-8976                                       NaN
#
#                D_19_07_Annexed2_Marchecomplementaire  \
# BOAMP_AVIS_NUM
# 20-186                                           NaN
# 20-8603                                          NaN
# 20-8635                                          NaN
# 20-9196                                          NaN
# 20-9689                                          NaN
# 21-13108                                         NaN
# 21-13154                                         NaN
# 21-4265                                          NaN
# 21-4817                                          NaN
# 21-8976                                          NaN
#
#                D_19_08_Annexed2_Prestationsidentiques  \
# BOAMP_AVIS_NUM
# 20-186                                            NaN
# 20-8603                                           NaN
# 20-8635                                           NaN
# 20-9196                                           NaN
# 20-9689                                           NaN
# 21-13108                                          NaN
# 21-13154                                          NaN
# 21-4265                                           NaN
# 21-4817                                           NaN
# 21-8976                                           NaN
#
#                D_19_09_Annexed2_Laureatsconcours  \
# BOAMP_AVIS_NUM
# 20-186                                       NaN
# 20-8603                                      NaN
# 20-8635                                      NaN
# 20-9196                                      NaN
# 20-9689                                      NaN
# 21-13108                                     NaN
# 21-13154                                     NaN
# 21-4265                                      NaN
# 21-4817                                      NaN
# 21-8976                                      NaN
#
#                D_19_10_Annexed2_Matierespremieres  \
# BOAMP_AVIS_NUM
# 20-186                                        NaN
# 20-8603                                       NaN
# 20-8635                                       NaN
# 20-9196                                       NaN
# 20-9689                                       NaN
# 21-13108                                      NaN
# 21-13154                                      NaN
# 21-4265                                       NaN
# 21-4817                                       NaN
# 21-8976                                       NaN
#
#                D_19_11_Annexed2_Cessationactivite  \
# BOAMP_AVIS_NUM
# 20-186                                        NaN
# 20-8603                                       NaN
# 20-8635                                       NaN
# 20-9196                                       NaN
# 20-9689                                       NaN
# 21-13108                                      NaN
# 21-13154                                      NaN
# 21-4265                                       NaN
# 21-4817                                       NaN
# 21-8976                                       NaN
#
#                D_19_12_Annexed2_Liquidateurs  \
# BOAMP_AVIS_NUM
# 20-186                                   NaN
# 20-8603                                  NaN
# 20-8635                                  NaN
# 20-9196                                  NaN
# 20-9689                                  NaN
# 21-13108                                 NaN
# 21-13154                                 NaN
# 21-4265                                  NaN
# 21-4817                                  NaN
# 21-8976                                  NaN
#
#                D_19_13_Annexed2_Achatopportunite D_19_14_Annexed2_Horsscope  \
# BOAMP_AVIS_NUM
# 20-186                                       NaN                      False
# 20-8603                                      NaN                      False
# 20-8635                                      NaN                      False
# 20-9196                                      NaN                      False
# 20-9689                                      NaN                       True
# 21-13108                                     NaN                       True
# 21-13154                                     NaN                      False
# 21-4265                                      NaN                      False
# 21-4817                                      NaN                      False
# 21-8976                                      NaN                      False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            D_19_15_Annexed2_Explication
# BOAMP_AVIS_NUM
# 20-186          <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Dans le cadre de la réalisation de la seconde ligne du tramway Valenciennois, le SIMOUV, a souscrit un marché public portant sur la réalisation de prestations relatives à la signalisation ferroviaire.Le titulaire avait notamment pour mission de fournir un système danti- franchissement sur les rames, dispositif sécuritaire visant à empêcher le franchissement dun feu de signalisation rouge. Cet ensemble sécuritaire est constitué dun ensemble déquipements embarqués à bord des tramways composé de capteurs embarqués (CE KFS), de calculateurs embarqués (BE KFS) et de balises au sol.A ce titre, depuis la mise en service de la ligne T2 en février 2014, lexploitant a déploré de multiples dysfonctionnements (freinage durgence aléatoire en labsence de franchissement des feux, perte des CE en exploitation, ...) lesquels ont été constatés et dénoncés auprès du titulaire du marché ainsi que du maître duvre de lopération (société INGEROP CONSEIL &amp;amp; INGENIERIE).Compte tenu des contraintes sécuritaires, le SIMOUV a sollicité la juridiction administrative, au travers dune requête en référé-expertise déposée le 29 juillet 2015 en vue de la désignation dun Expert judiciaire avec notamment pour missions de définir la nature et létendue des modalités réparatoires ;Les opérations expertales ont notamment démontré la nécessité de remplacer les capteurs CE en vue de remédier aux désordres.Il ainsi ressort de lexpertise que les capteurs actuels ont subi de nombreux chocs et des accélérations pour lesquels ils nont pas été conçus. En conséquence, ces équipements susent de manière prématurée et nécessitent dêtre remplacés dans leur intégralité.  Par ailleurs, afin de concevoir un nouveau système de supportage, différents essais ont été menés en laboratoire et sur site avec des capteurs CE développés par la société CLEARSY (modèle référencé AM-ME-015-008). Dès lors, le SIMOUV est tenu de procéder à lacquisition de ces capteurs auprès de la société CLEARSY. En effet, le changement de fournisseur conduirait à la réalisation de nouvelles études de conception du système de supportage, à de nouveaux essais et au remplacement des balises au sol.Ainsi, compte tenu de ces motifs techniques, une consultation a été lancée en vue de la passation dun marché public sans publicité ni mise ni mise en concurrence préalables avec la société CLEARSY, conformément aux articles L.2122-1 et R.2122-3-2° du CCP.</EXPLICATION>
# 20-8603                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Le ferry boat est un bateau électro solaire développé spécifiquement pour la ville de Marseille. Sa conception est issu d'un consortium inédit où la partie énergie et batteries ont été réalisés par la société Alternatives Energies. Alternatives Energies a donc conçu le système de gestion des batteries (BMS) ainsi que le système de stockage de batteries spécifiquement pour ce bateau. A ce jour, les batteries sont en fin de vie et ne permettent plus d'exploiter le ferry boat. Or les batteries actuelles, ainsi que leur technologie en Nickel Cadium ne sont plus fabriquées. Ainsi, nous sommes contraints de changer de technologie de batteries en passant à une technologie moderne à base de Lithium. Ce changement impose une réactualisation du BMS. Il est donc nécessaire de faire appel au constructeur d'origine pour le réaliser.</EXPLICATION>
# 20-8635                         <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">La passation du présent accord-cadre par le GPMD na pas de finalité commerciale immédiate, cest-à-dire un objectif de rentabilité ou de récupération des coûts engagés à titre de recherche et de développement. Les prestations objets de laccord-cadre doivent être exécutées uniquement dans lobjectif de faire lobjet de recherche au titre des missions règlementaires du GPMD de gestion et de préservation du domaine public naturel et des espaces naturels dont il est propriétaire ou qui lui sont affectés incluant la surveillance littorale des mammifères marins. Dunkerque-Port doit sappuyer sur lexpertise du laboratoire dOcéanologie et de Géosciences (LOG) de lUniversité du littoral Côte dOpale avec lappui technique de lassociation Coordination Mammalogique du Nord de la France (CMNF) et du laboratoire en pathologie animale de la Faculté de Médecine Vétérinaire de lUniversité de Liège afin de réaliser cette mission.La Coordination Mammalogique du Nord de la France (CMNF), réalise tout au long de l'année des suivis des populations sur les diverses espèces de mammifères marins du littoral des Hauts de France. La circulaire interministérielle (no DNP/CFF N°01/01) du 18 octobre 2001 relative aux échouages de mammifères marins en France, reconnait la valeur dobservatoire du suivi des échouages de mammifères marins et lorganisation du Réseau National dEchouages. Cette circulaire précise par ailleurs les conditions dintervention sur des animaux échoués : en particulier chacun des correspondants du Réseau National dEchouage au moyen dune carte verte est seul autorisé à intervenir sur ces espèces protégées. De ce fait, seules 21 personnes de la CMNF peuvent prélever, transporter et utiliser des spécimens de mammifères marins à des fins danalyses scientifiques sur les départements 59 et 62. La CMNF, seule habilitée à manipuler et à transporter les mammifères marins, a pour partenaires techniques habituels : le laboratoire en pathologie animale de lUniversité de Liège pour la détermination de létat de santé des animaux, notamment virologie, bactériologie et parasitologie, ainsi que léquipe " Ecosystèmes, biodiversité et changements globaux " du laboratoire dOcéanologie et de Géosciences de lUniversité du littoral Côte dOpale (LOG) pour les investigations chimiques et lappréciation des impacts potentiels des activités industrialo-portuaires sur les espèces marines.</EXPLICATION>
# 20-9196                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">La société INEO E&amp;amp;S a fourni à la DTI une attestation des droits de propriété exclusive concernant les systèmes/produits RAIATEA. Cette attestation stipule notamment que INEO E&amp;amp;S est la seule entité juridique à détenir la propriété intellectuelle du système de chaîne radio et téléphone de sécurité à destination des contrôleurs aériens dénommé RAIATEA et donc à pouvoir maintenir ses équipements, développer les correctifs et évolutions de ce dernier.</EXPLICATION>
# 20-9689                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Marché passé en procédure adaptée.</EXPLICATION>
# 21-13108                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Conduent Business Solution certifie que les produits type Billetterie proposés dans le cadre du système billettique de la Communauté Urbaine Marseille Provence Métropole, sont étudiés et développées par Conduent Business Solution.Conduent Business Solution certifie que les plans, schémas, restent la propriété exclusive de la société. </EXPLICATION>
# 21-13154                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Seule la société CPI pérennise la fabrication de magnétrons compatibles avec les radars ASTRE. Les magnétrons de cette société américaine sont distribués en France par la société Richardson. </EXPLICATION>
# 21-4265                                                                                                                                                                                                                                                                                                                                                                                                                                                <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Larticle R. 2122-3 du code de la commande publique prévoit que " lacheteur peut passer un marché sans publicité ni mise en concurrence préalables lorsque les travaux, fournitures ou services ne peuvent être fournis que par un opérateur économique déterminé " notamment pour " des raisons techniques ", étant précisé que " le recours à un opérateur déterminé nest justifié que lorsquil nexiste aucune solution de remplacement raisonnable et que labsence de concurrence ne résulte pas dune restriction artificielle des caractéristiques du marché. Ces raisons techniques peuvent par exemple découler dexigences spécifiques dinteropérabilité (voir considérant 50 du préambule de la directive 2014/24/UE du Parlement européen et du Conseil du 26 février 2014 sur la passation des marchés publics ; voir pour des exemples : CE, 21 mai 1986, société Schlumberger, req. no 56848 ; CE, 19 septembre 2007, Communauté dagglomération de Saint-Etienne Métropole, req. no 296192, Rec., T.). Ainsi, des risques dinterférences techniques liés à létroite connexion des travaux constituent des motifs dordre technique car générant des difficultés dexécution réelles. En l'espèce, louvrage dart MS06, bien quil soit indépendant, est imbriqué entre plusieurs ouvrages adjacents en cours de réalisation.  Or, cet ouvrage doit faire lobjet dune conception et dune réalisation cohérente avec lOuvrage d'art numéro 4 adjacent.Celui-ci, conçu par la maîtrise duvre lot no2 du Tram 12 (marché 2012-067) et réalisé par lentreprise travaux " OAG1 " supporte une station de tramway conçue par une la maîtrise duvre générale et réalisée par plusieurs entreprises travaux en fonction des corps de métiers : voie ferrée, ligne aérienne de contact, ... en surplomb de lautoroute A6. Des interfaces foncières, spatiales, lithologiques et liées à la conception des autres ouvrages ne permettent pas la mobilisation dautres opérateurs économiques que le groupement de MOE actuel pour concevoir cet ouvrage MS06.   </EXPLICATION>
# 21-4817                                                                                                                                                                                                                                                                                                                                                                                                                          <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Larticle R. 2122-3 du code de la commande publique prévoit que " lacheteur peut passer un marché sans publicité ni mise en concurrence préalables lorsque les travaux, fournitures ou services ne peuvent être fournis que par un opérateur économique déterminé " notamment pour " des raisons techniques ", étant précisé que " le recours à un opérateur déterminé nest justifié que lorsquil nexiste aucune solution de remplacement raisonnable et que labsence de concurrence ne résulte pas dune restriction artificielle des caractéristiques du marché. Ces raisons techniques peuvent par exemple découler dexigences spécifiques dinteropérabilité (voir considérant 50 du préambule de la directive 2014/24/UE du Parlement européen et du Conseil du 26 février 2014 sur la passation des marchés publics ; voir pour des exemples : CE, 21 mai 1986, société Schlumberger, req. no 56848 ; CE, 19 septembre 2007, Communauté dagglomération de Saint-Etienne Métropole, req. no 296192, Rec., T.). Ainsi, des risques dinterférences techniques liés à létroite connexion des travaux constituent des motifs dordre technique car générant des difficultés dexécution réelles. En l'espèce, louvrage dart MS06, bien quil soit indépendant, est imbriqué entre plusieurs ouvrages adjacents en cours de réalisation. Or, cet ouvrage doit faire lobjet dune conception et dune réalisation cohérente avec lOuvrage d'art numéro 4 adjacent. Celui-ci, conçu par la maîtrise duvre lot no2 du Tram 12 (marché 2012-067) et réalisé par lentreprise travaux " OAG1 " supporte une station de tramway conçue par une la maîtrise duvre générale et réalisée par plusieurs entreprises travaux en fonction des corps de métiers : voie ferrée, ligne aérienne de contact, ... en surplomb de lautoroute A6. Des interfaces foncières, spatiales, lithologiques et liées à la conception des autres ouvrages ne permettent pas la mobilisation dautres opérateurs économiques que le groupement titulaire du marché de travaux " OAG1 " pour réaliser cet ouvrage MS06.</EXPLICATION>
# 21-8976                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">La société Kieoe Electric Ges.m.b.H, filiale à 100% du groupe Knorr-Bremse, possède les droits exclusifs de propriétés intellectuelles pour l'ensemble des pièces du marché.</EXPLICATION>

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
