# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_G_03_Nomhtml_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table G_03_Nomhtml BOAMP 2020-2021 pour Python

# %%
# La table G 03 n'est pas utilisée car son information se limite à lister l'index déja présent par ailleurs.
