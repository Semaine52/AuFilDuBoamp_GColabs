# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_21_Annexed4_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_21_Annexed4 BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_21_annexed4.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_21_annexed4.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_21_annexed4.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_21' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_21' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 19-193199 to 21-17392
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   D_21_01_Annexed4_Infructueux              10 non-null     bool
#  1   D_21_02_Annexed4_Raisonstechniques        10 non-null     bool
#  2   D_21_03_Annexed4_Raisonsartistiques       10 non-null     bool
#  3   D_21_04_Annexed4_Raisonsexclusivites      10 non-null     bool
#  4   D_21_05_Annexed4_Proprieteintellectuelle  0 non-null      float64
#  5   D_21_06_Annexed4_Horsscope                10 non-null     bool
#  6   D_21_07_Annexed4_Explication              10 non-null     object
# dtypes: bool(5), float64(1), object(1)
# memory usage: 290.0+ bytes

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                 D_21_01_Annexed4_Infructueux  \
# BOAMP_AVIS_NUM
# 19-193199                              False
# 20-11528                               False
# 20-12818                               False
# 20-13822                               False
# 20-14644                                True
# 21-11975                               False
# 21-5069                                False
# 21-9217                                False
# 18-111639                              False
# 21-17392                               False
#
#                 D_21_02_Annexed4_Raisonstechniques  \
# BOAMP_AVIS_NUM
# 19-193199                                    False
# 20-11528                                     False
# 20-12818                                     False
# 20-13822                                     False
# 20-14644                                     False
# 21-11975                                     False
# 21-5069                                      False
# 21-9217                                      False
# 18-111639                                    False
# 21-17392                                     False
#
#                 D_21_03_Annexed4_Raisonsartistiques  \
# BOAMP_AVIS_NUM
# 19-193199                                     False
# 20-11528                                      False
# 20-12818                                      False
# 20-13822                                      False
# 20-14644                                      False
# 21-11975                                      False
# 21-5069                                       False
# 21-9217                                       False
# 18-111639                                      True
# 21-17392                                      False
#
#                 D_21_04_Annexed4_Raisonsexclusivites  \
# BOAMP_AVIS_NUM
# 19-193199                                       True
# 20-11528                                       False
# 20-12818                                       False
# 20-13822                                       False
# 20-14644                                       False
# 21-11975                                        True
# 21-5069                                        False
# 21-9217                                         True
# 18-111639                                      False
# 21-17392                                       False
#
#                 D_21_05_Annexed4_Proprieteintellectuelle  \
# BOAMP_AVIS_NUM
# 19-193199                                            NaN
# 20-11528                                             NaN
# 20-12818                                             NaN
# 20-13822                                             NaN
# 20-14644                                             NaN
# 21-11975                                             NaN
# 21-5069                                              NaN
# 21-9217                                              NaN
# 18-111639                                            NaN
# 21-17392                                             NaN
#
#                 D_21_06_Annexed4_Horsscope  \
# BOAMP_AVIS_NUM
# 19-193199                            False
# 20-11528                              True
# 20-12818                              True
# 20-13822                              True
# 20-14644                             False
# 21-11975                             False
# 21-5069                               True
# 21-9217                              False
# 18-111639                            False
# 21-17392                              True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  D_21_07_Annexed4_Explication
# BOAMP_AVIS_NUM
# 19-193199                                                                  <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">L'article 14 1 de l'ordonnance n 2016-65 du 29.1.2016 relative aux contrats de concession exclut de son champ d'application les contrats de concession de services conclus avec un opérateur économique lorsqu'il bénéficie d'un droit exclusif.Au cas d'espèce, l'article L. 111-53 du Code de l'énergie dispose que GRDF assure la gestion des réseaux publics de distribution de gaz naturel dans sa zone de desserte exclusive. En conséquence, le renouvellement du traité de concession se fera au profit de GRDF sans publicité préalable ni mise en concurrence.</EXPLICATION>
# 20-11528                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Existence d'un droit exclusif</EXPLICATION>
# 20-12818                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Enedis et EDF bénéficient de droits exclusifs consacrés par la législation nationale ( article L.111-52; L. 121-5 et L .334-3 du code de l'énergie)</EXPLICATION>
# 20-13822                                                                                                                                                                                    <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">De par leurs caractéristiques; les concessions de distribution publique d'énergie électrique répondent à la définition de la délégation de services publics. Toutefois, au regard du droit interne, elles sont exclues du champ des dispositions de la "loi sapin" applicables aux délégations de services publics du fait du monopole institué par la loi aux opérateurs concernés (article L.411-12 du code général des collectivités territoriales).</EXPLICATION>
# 20-14644                                                                                                                                                                                                                                                                                                                                                                                                                          <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">La procédure sans mise en concurrence fait suite à une première procédure infructueuse. En vertu de l'article L 3121-2 du code de la commande publique, la collectivité a recours à une procédure sans publicité.</EXPLICATION>
# 21-11975                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Articles L.111-52, L.121-5 et L.334-3 du code de l'eÌnergie. Article L.2224-31 du code geÌneÌral des collectiviteÌs territoriales</EXPLICATION>
# 21-5069                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Contrat dont la valeur est inférieure au seuil européen</EXPLICATION>
# 21-9217                                                                                                                                                                                                                                                                                                                                                                                                                                          <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Explication:Article L. 111-52 du code de l'énergie.Article L. 121-5 du code de l'énergie.Article L. 334-3 du code de l'énergie.Article L. 2234-31 du code général des collectivités territoriales.</EXPLICATION>
# 18-111639                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Enedis et EDF bénéficient de droits exclusifs consacres par la législation nationale (articles L. 111-52, L. 121-5 et L. 334-3 du code de l'énergie).</EXPLICATION>
# 21-17392        <?xml version="1.0" encoding="UTF-16"?>\n<EXPLICATION xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">Le contrat de concession pour le service public du développement et de lexploitation du réseau de distribution délectricité et de la fourniture dénergie aux tarifs réglementés de vente entre dans le champ des dispositions de larticle L. 3221-1 du Code de la commande publique qui exonère des règles de publicité et de mise en concurrence les contrats de concession conclus avec un opérateur économique qui bénéficie dun droit exclusif en vertu dune disposition légalement prise. En effet, ENEDIS et EDF bénéficient de droits exclusifs consacrés par le Code de lénergie (articles L. 111-52  et L. 121-5). </EXPLICATION>

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
