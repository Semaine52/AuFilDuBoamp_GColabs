# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_15_Conditionadministrative_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_15_Conditionadministrative  BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_15_conditionadministrative.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_15_conditionadministrative.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_15_conditionadministrative.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_15' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_15' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 17-23813 to 19-180078
# Data columns (total 25 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   D_15_01_Conditionadministrative_Referencemarche                           3 non-null      object
#  1   D_15_02_Conditionadministrative_Etudesconcours                            0 non-null      object
#  2   D_15_03_Conditionadministrative_Recompenseslaureatoui                     10 non-null     bool
#  3   D_15_04_Conditionadministrative_Recompensesaureatnon                      10 non-null     bool
#  4   D_15_05_Conditionadministrative_Recompenseslaureat                        0 non-null      object
#  5   D_15_06_Conditionadministrative_Indemnisationparticipants                 0 non-null      object
#  6   D_15_07_Conditionadministrative_Conditionsremiseoffres                    2 non-null      object
#  7   D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments  1 non-null      object
#  8   D_15_09_Conditionadministrative_Datelimiteobtentiondocuments              0 non-null      object
#  9   D_15_10_Conditionadministrative_Documentpayantoui                         10 non-null     object
#  10  D_15_10_01_Conditionadministrative_Documentpayantoui_Valeur               10 non-null     object
#  11  D_15_10_01_01_Conditionadministrative_Documentpayantoui_Valeur_Value      0 non-null      float64
#  12  D_15_10_01_02_Conditionadministrative_Documentpayantoui_Valeur_Devise     0 non-null      object
#  13  D_15_11_Conditionadministrative_Documentpayantnon                         10 non-null     bool
#  14  D_15_12_Conditionadministrative_Persouvertureoffresoui                    2 non-null      object
#  15  D_15_13_Conditionadministrative_Persouvertureoffresnon                    10 non-null     bool
#  16  D_15_14_Conditionadministrative_Datedebutattribution                      0 non-null      object
#  17  D_15_15_Conditionadministrative_Dateouvertureoffres                       3 non-null      object
#  18  D_15_16_Conditionadministrative_Lieuouvertureoffres                       1 non-null      object
#  19  D_15_17_Conditionadministrative_Abandonsadoui                             0 non-null      object
#  20  D_15_18_Conditionadministrative_Abandonsadnon                             10 non-null     bool
#  21  D_15_19_Conditionadministrative_Finattributionoui                         10 non-null     bool
#  22  D_15_20_Conditionadministrative_Finattributionnon                         10 non-null     bool
#  23  D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui             10 non-null     bool
#  24  D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon             10 non-null     bool
# dtypes: bool(9), float64(1), object(15)
# memory usage: 1.4+ KB

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                D_15_01_Conditionadministrative_Referencemarche  \
# BOAMP_AVIS_NUM
# 17-23813                                                   NaN
# 18-78695                                               2020-02
# 19-102527                                               S19032
# 19-109490                                                  NaN
# 19-109992                                                  NaN
# 21-37182                                                   NaN
# 19-141762                                                  NaN
# 19-170952                                                  NaN
# 19-174419                                            2020-0168
# 19-180078                                                  NaN
#
#                D_15_02_Conditionadministrative_Etudesconcours  \
# BOAMP_AVIS_NUM
# 17-23813                                                  NaN
# 18-78695                                                  NaN
# 19-102527                                                 NaN
# 19-109490                                                 NaN
# 19-109992                                                 NaN
# 21-37182                                                  NaN
# 19-141762                                                 NaN
# 19-170952                                                 NaN
# 19-174419                                                 NaN
# 19-180078                                                 NaN
#
#                 D_15_03_Conditionadministrative_Recompenseslaureatoui  \
# BOAMP_AVIS_NUM
# 17-23813                                                        False
# 18-78695                                                        False
# 19-102527                                                       False
# 19-109490                                                       False
# 19-109992                                                       False
# 21-37182                                                        False
# 19-141762                                                       False
# 19-170952                                                       False
# 19-174419                                                       False
# 19-180078                                                       False
#
#                 D_15_04_Conditionadministrative_Recompensesaureatnon  \
# BOAMP_AVIS_NUM
# 17-23813                                                       False
# 18-78695                                                       False
# 19-102527                                                      False
# 19-109490                                                      False
# 19-109992                                                      False
# 21-37182                                                       False
# 19-141762                                                      False
# 19-170952                                                      False
# 19-174419                                                      False
# 19-180078                                                      False
#
#                D_15_05_Conditionadministrative_Recompenseslaureat  \
# BOAMP_AVIS_NUM
# 17-23813                                                      NaN
# 18-78695                                                      NaN
# 19-102527                                                     NaN
# 19-109490                                                     NaN
# 19-109992                                                     NaN
# 21-37182                                                      NaN
# 19-141762                                                     NaN
# 19-170952                                                     NaN
# 19-174419                                                     NaN
# 19-180078                                                     NaN
#
#                D_15_06_Conditionadministrative_Indemnisationparticipants  \
# BOAMP_AVIS_NUM
# 17-23813                                                             NaN
# 18-78695                                                             NaN
# 19-102527                                                            NaN
# 19-109490                                                            NaN
# 19-109992                                                            NaN
# 21-37182                                                             NaN
# 19-141762                                                            NaN
# 19-170952                                                            NaN
# 19-174419                                                            NaN
# 19-180078                                                            NaN
#
#                                                                                  D_15_07_Conditionadministrative_Conditionsremiseoffres  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                            NaN
# 18-78695                 Les offres et les candidatures devront être remises par voie dématérialisée sur la plateforme des achats PLACE
# 19-102527       Remise des offres sur le profil d'acheteur du pouvoir adjudicateur, à l'adresse URL suivante : https://www.xmarches.fr.
# 19-109490                                                                                                                           NaN
# 19-109992                                                                                                                           NaN
# 21-37182                                                                                                                            NaN
# 19-141762                                                                                                                           NaN
# 19-170952                                                                                                                           NaN
# 19-174419                                                                                                                           NaN
# 19-180078                                                                                                                           NaN
#
#                                                                                                                     D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                                                                                 NaN
# 18-78695                                                                                                                                                                                 NaN
# 19-102527       La transmission des documents se fait uniquement par voie électronique sur le profil d'acheteur du pouvoir adjudicateur, à l'adresse URL suivante : https://www.xmarches.fr.
# 19-109490                                                                                                                                                                                NaN
# 19-109992                                                                                                                                                                                NaN
# 21-37182                                                                                                                                                                                 NaN
# 19-141762                                                                                                                                                                                NaN
# 19-170952                                                                                                                                                                                NaN
# 19-174419                                                                                                                                                                                NaN
# 19-180078                                                                                                                                                                                NaN
#
#                D_15_09_Conditionadministrative_Datelimiteobtentiondocuments  \
# BOAMP_AVIS_NUM
# 17-23813                                                                NaN
# 18-78695                                                                NaN
# 19-102527                                                               NaN
# 19-109490                                                               NaN
# 19-109992                                                               NaN
# 21-37182                                                                NaN
# 19-141762                                                               NaN
# 19-170952                                                               NaN
# 19-174419                                                               NaN
# 19-180078                                                               NaN
#
#                D_15_10_Conditionadministrative_Documentpayantoui  \
# BOAMP_AVIS_NUM
# 17-23813                                             CF_NIV_SUIV
# 18-78695                                             CF_NIV_SUIV
# 19-102527                                            CF_NIV_SUIV
# 19-109490                                            CF_NIV_SUIV
# 19-109992                                            CF_NIV_SUIV
# 21-37182                                             CF_NIV_SUIV
# 19-141762                                            CF_NIV_SUIV
# 19-170952                                            CF_NIV_SUIV
# 19-174419                                            CF_NIV_SUIV
# 19-180078                                            CF_NIV_SUIV
#
#                D_15_10_01_Conditionadministrative_Documentpayantoui_Valeur  \
# BOAMP_AVIS_NUM
# 17-23813                                                       CF_NIV_SUIV
# 18-78695                                                       CF_NIV_SUIV
# 19-102527                                                      CF_NIV_SUIV
# 19-109490                                                      CF_NIV_SUIV
# 19-109992                                                      CF_NIV_SUIV
# 21-37182                                                       CF_NIV_SUIV
# 19-141762                                                      CF_NIV_SUIV
# 19-170952                                                      CF_NIV_SUIV
# 19-174419                                                      CF_NIV_SUIV
# 19-180078                                                      CF_NIV_SUIV
#
#                 D_15_10_01_01_Conditionadministrative_Documentpayantoui_Valeur_Value  \
# BOAMP_AVIS_NUM
# 17-23813                                                                         NaN
# 18-78695                                                                         NaN
# 19-102527                                                                        NaN
# 19-109490                                                                        NaN
# 19-109992                                                                        NaN
# 21-37182                                                                         NaN
# 19-141762                                                                        NaN
# 19-170952                                                                        NaN
# 19-174419                                                                        NaN
# 19-180078                                                                        NaN
#
#                D_15_10_01_02_Conditionadministrative_Documentpayantoui_Valeur_Devise  \
# BOAMP_AVIS_NUM
# 17-23813                                                                         NaN
# 18-78695                                                                         NaN
# 19-102527                                                                        NaN
# 19-109490                                                                        NaN
# 19-109992                                                                        NaN
# 21-37182                                                                         NaN
# 19-141762                                                                        NaN
# 19-170952                                                                        NaN
# 19-174419                                                                        NaN
# 19-180078                                                                        NaN
#
#                 D_15_11_Conditionadministrative_Documentpayantnon  \
# BOAMP_AVIS_NUM
# 17-23813                                                    False
# 18-78695                                                    False
# 19-102527                                                   False
# 19-109490                                                   False
# 19-109992                                                   False
# 21-37182                                                    False
# 19-141762                                                   False
# 19-170952                                                   False
# 19-174419                                                   False
# 19-180078                                                   False
#
#                       D_15_12_Conditionadministrative_Persouvertureoffresoui  \
# BOAMP_AVIS_NUM
# 17-23813        Les offres seront ouvertes au siège de CRETEIL-HABITAT-SEMIC
# 18-78695                                                                 NaN
# 19-102527                                                                NaN
# 19-109490                                                                NaN
# 19-109992                                                                NaN
# 21-37182                                                                 NaN
# 19-141762                                                Séance non publique
# 19-170952                                                                NaN
# 19-174419                                                                NaN
# 19-180078                                                                NaN
#
#                 D_15_13_Conditionadministrative_Persouvertureoffresnon  \
# BOAMP_AVIS_NUM
# 17-23813                                                         False
# 18-78695                                                         False
# 19-102527                                                        False
# 19-109490                                                        False
# 19-109992                                                        False
# 21-37182                                                         False
# 19-141762                                                        False
# 19-170952                                                        False
# 19-174419                                                        False
# 19-180078                                                        False
#
#                D_15_14_Conditionadministrative_Datedebutattribution  \
# BOAMP_AVIS_NUM
# 17-23813                                                        NaN
# 18-78695                                                        NaN
# 19-102527                                                       NaN
# 19-109490                                                       NaN
# 19-109992                                                       NaN
# 21-37182                                                        NaN
# 19-141762                                                       NaN
# 19-170952                                                       NaN
# 19-174419                                                       NaN
# 19-180078                                                       NaN
#
#                D_15_15_Conditionadministrative_Dateouvertureoffres  \
# BOAMP_AVIS_NUM
# 17-23813                                       2020-03-18 00:00:00
# 18-78695                                                       NaN
# 19-102527                                                      NaN
# 19-109490                                                      NaN
# 19-109992                                                      NaN
# 21-37182                                                       NaN
# 19-141762                                      2021-02-12 00:00:00
# 19-170952                                                      NaN
# 19-174419                                                      NaN
# 19-180078                                      2021-02-23 00:00:00
#
#                D_15_16_Conditionadministrative_Lieuouvertureoffres  \
# BOAMP_AVIS_NUM
# 17-23813                                                       NaN
# 18-78695                                                       NaN
# 19-102527                                                      NaN
# 19-109490                                                      NaN
# 19-109992                                                      NaN
# 21-37182                                                       NaN
# 19-141762                                                      NaN
# 19-170952                                                      NaN
# 19-174419                                                      NaN
# 19-180078                                             Vaux-sur-Mer
#
#                D_15_17_Conditionadministrative_Abandonsadoui  \
# BOAMP_AVIS_NUM
# 17-23813                                                 NaN
# 18-78695                                                 NaN
# 19-102527                                                NaN
# 19-109490                                                NaN
# 19-109992                                                NaN
# 21-37182                                                 NaN
# 19-141762                                                NaN
# 19-170952                                                NaN
# 19-174419                                                NaN
# 19-180078                                                NaN
#
#                 D_15_18_Conditionadministrative_Abandonsadnon  \
# BOAMP_AVIS_NUM
# 17-23813                                                False
# 18-78695                                                False
# 19-102527                                               False
# 19-109490                                                True
# 19-109992                                                True
# 21-37182                                                 True
# 19-141762                                               False
# 19-170952                                               False
# 19-174419                                               False
# 19-180078                                               False
#
#                 D_15_19_Conditionadministrative_Finattributionoui  \
# BOAMP_AVIS_NUM
# 17-23813                                                    False
# 18-78695                                                    False
# 19-102527                                                   False
# 19-109490                                                   False
# 19-109992                                                   False
# 21-37182                                                    False
# 19-141762                                                   False
# 19-170952                                                   False
# 19-174419                                                   False
# 19-180078                                                   False
#
#                 D_15_20_Conditionadministrative_Finattributionnon  \
# BOAMP_AVIS_NUM
# 17-23813                                                    False
# 18-78695                                                    False
# 19-102527                                                   False
# 19-109490                                                    True
# 19-109992                                                    True
# 21-37182                                                     True
# 19-141762                                                   False
# 19-170952                                                   False
# 19-174419                                                   False
# 19-180078                                                   False
#
#                 D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui  \
# BOAMP_AVIS_NUM
# 17-23813                                                                False
# 18-78695                                                                False
# 19-102527                                                               False
# 19-109490                                                               False
# 19-109992                                                               False
# 21-37182                                                                False
# 19-141762                                                               False
# 19-170952                                                               False
# 19-174419                                                               False
# 19-180078                                                               False
#
#                 D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon
# BOAMP_AVIS_NUM
# 17-23813                                                                 True
# 18-78695                                                                False
# 19-102527                                                               False
# 19-109490                                                               False
# 19-109992                                                               False
# 21-37182                                                                False
# 19-141762                                                                True
# 19-170952                                                                True
# 19-174419                                                               False
# 19-180078                                                                True

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
