# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_04_Activiteprincipale_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_04_Activiteprincipale BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
#
# Plein écran ► https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_04_activiteprincipale.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_04_activiteprincipale.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_04_activiteprincipale.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# fatal: destination path 'AuFilDuBoamp_Outils_CSV' already exists and is not an empty directory.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_04' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_04' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 17-23813 to 19-174419
# Data columns (total 18 columns):
#  #   Column                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                         --------------  -----
#  0   D_04_01_Activiteprincipale_Pouvoiradjudicateur                                                                                 10 non-null     bool
#  1   D_04_01_01_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE                                                    10 non-null     object
#  2   D_04_01_01_01_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Name                                            10 non-null     object
#  3   D_04_01_01_02_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_DeclaredType                                    10 non-null     object
#  4   D_04_01_01_03_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Scope                                           10 non-null     object
#  5   D_04_01_01_04_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Value                                           10 non-null     object
#  6   D_04_01_01_05_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Nil                                             10 non-null     bool
#  7   D_04_01_01_06_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_GlobalScope                                     10 non-null     bool
#  8   D_04_01_01_07_Activiteprincipale_Pouvoiradjudicateur_deforACTSERVADMPUBOrSANTE_TypeSubstituted                                 10 non-null     bool
#  9   D_04_02_Activiteprincipale_Entiteadjudicatrice                                                                                 10 non-null     object
#  10  D_04_02_01_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ                     10 non-null     object
#  11  D_04_02_01_01_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Name             0 non-null      object
#  12  D_04_02_01_02_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_DeclaredType     0 non-null      object
#  13  D_04_02_01_03_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Scope            0 non-null      object
#  14  D_04_02_01_04_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Value            0 non-null      object
#  15  D_04_02_01_05_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Nil              0 non-null      object
#  16  D_04_02_01_06_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_GlobalScope      10 non-null     bool
#  17  D_04_02_01_07_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_TypeSubstituted  10 non-null     bool
# dtypes: bool(6), object(12)
# memory usage: 1.1+ KB

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                 D_04_01_Activiteprincipale_Pouvoiradjudicateur  \
# BOAMP_AVIS_NUM
# 17-23813                                                  True
# 18-55590                                                  True
# 18-78695                                                  True
# 19-109490                                                 True
# 19-109992                                                 True
# 11-116542                                                 True
# 21-37182                                                  True
# 19-141762                                                 True
# 19-170952                                                 True
# 19-174419                                                 True
#
#                D_04_01_01_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE  \
# BOAMP_AVIS_NUM
# 17-23813                                                                       CF_NIV_SUIV
# 18-55590                                                                       CF_NIV_SUIV
# 18-78695                                                                       CF_NIV_SUIV
# 19-109490                                                                      CF_NIV_SUIV
# 19-109992                                                                      CF_NIV_SUIV
# 11-116542                                                                      CF_NIV_SUIV
# 21-37182                                                                       CF_NIV_SUIV
# 19-141762                                                                      CF_NIV_SUIV
# 19-170952                                                                      CF_NIV_SUIV
# 19-174419                                                                      CF_NIV_SUIV
#
#                D_04_01_01_01_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Name  \
# BOAMP_AVIS_NUM
# 17-23813                                                                               LOG_DEV_COL
# 18-55590                                                                          ACT_SERV_ADM_PUB
# 18-78695                                                                                     AUTRE
# 19-109490                                                                         ACT_SERV_ADM_PUB
# 19-109992                                                                                    AUTRE
# 11-116542                                                                         ACT_SERV_ADM_PUB
# 21-37182                                                                          ACT_SERV_ADM_PUB
# 19-141762                                                                         ACT_SERV_ADM_PUB
# 19-170952                                                                                    AUTRE
# 19-174419                                                                         ACT_SERV_ADM_PUB
#
#                D_04_01_01_02_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_DeclaredType  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                  java.lang.Object
# 18-55590                                                                                  java.lang.Object
# 18-78695                                                                                  java.lang.String
# 19-109490                                                                                 java.lang.Object
# 19-109992                                                                                 java.lang.String
# 11-116542                                                                                 java.lang.Object
# 21-37182                                                                                  java.lang.Object
# 19-141762                                                                                 java.lang.Object
# 19-170952                                                                                 java.lang.String
# 19-174419                                                                                 java.lang.Object
#
#                D_04_01_01_03_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Scope  \
# BOAMP_AVIS_NUM
# 17-23813                          fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 18-55590                          fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 18-78695                          fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 19-109490                         fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 19-109992                         fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 11-116542                         fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 21-37182                          fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 19-141762                         fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 19-170952                         fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
# 19-174419                         fr.gouv.dila.opendata.api.model.Boamp.Boamp_v230.EnumAdjudication
#
#                                                           D_04_01_01_04_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Value  \
# BOAMP_AVIS_NUM
# 17-23813                         <?xml version="1.0" encoding="UTF-16"?>\n<LOG_DEV_COL xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 18-55590                    <?xml version="1.0" encoding="UTF-16"?>\n<ACT_SERV_ADM_PUB xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 18-78695                                                                                                                             Recherche
# 19-109490                   <?xml version="1.0" encoding="UTF-16"?>\n<ACT_SERV_ADM_PUB xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 19-109992       Gestion d'équipements scolaires (collèges), protection sociale, eau, assainissement, voirie, aménagement urbain, déchets, etc.
# 11-116542                   <?xml version="1.0" encoding="UTF-16"?>\n<ACT_SERV_ADM_PUB xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 21-37182                    <?xml version="1.0" encoding="UTF-16"?>\n<ACT_SERV_ADM_PUB xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 19-141762                   <?xml version="1.0" encoding="UTF-16"?>\n<ACT_SERV_ADM_PUB xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 19-170952                                                                                                 activité de plage et de restauration
# 19-174419                   <?xml version="1.0" encoding="UTF-16"?>\n<ACT_SERV_ADM_PUB xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
#
#                 D_04_01_01_05_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_Nil  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                     False
# 18-55590                                                                                     False
# 18-78695                                                                                     False
# 19-109490                                                                                    False
# 19-109992                                                                                    False
# 11-116542                                                                                    False
# 21-37182                                                                                     False
# 19-141762                                                                                    False
# 19-170952                                                                                    False
# 19-174419                                                                                    False
#
#                 D_04_01_01_06_Activiteprincipale_Pouvoiradjudicateur_DeforACTSERVADMPUBOrSANTE_GlobalScope  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                             False
# 18-55590                                                                                             False
# 18-78695                                                                                             False
# 19-109490                                                                                            False
# 19-109992                                                                                            False
# 11-116542                                                                                            False
# 21-37182                                                                                             False
# 19-141762                                                                                            False
# 19-170952                                                                                            False
# 19-174419                                                                                            False
#
#                 D_04_01_01_07_Activiteprincipale_Pouvoiradjudicateur_deforACTSERVADMPUBOrSANTE_TypeSubstituted  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                  True
# 18-55590                                                                                                  True
# 18-78695                                                                                                 False
# 19-109490                                                                                                 True
# 19-109992                                                                                                False
# 11-116542                                                                                                 True
# 21-37182                                                                                                  True
# 19-141762                                                                                                 True
# 19-170952                                                                                                False
# 19-174419                                                                                                 True
#
#                D_04_02_Activiteprincipale_Entiteadjudicatrice  \
# BOAMP_AVIS_NUM
# 17-23813                                          CF_NIV_SUIV
# 18-55590                                          CF_NIV_SUIV
# 18-78695                                          CF_NIV_SUIV
# 19-109490                                         CF_NIV_SUIV
# 19-109992                                         CF_NIV_SUIV
# 11-116542                                         CF_NIV_SUIV
# 21-37182                                          CF_NIV_SUIV
# 19-141762                                         CF_NIV_SUIV
# 19-170952                                         CF_NIV_SUIV
# 19-174419                                         CF_NIV_SUIV
#
#                D_04_02_01_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                      CF_NIV_SUIV
# 18-55590                                                                                                      CF_NIV_SUIV
# 18-78695                                                                                                      CF_NIV_SUIV
# 19-109490                                                                                                     CF_NIV_SUIV
# 19-109992                                                                                                     CF_NIV_SUIV
# 11-116542                                                                                                     CF_NIV_SUIV
# 21-37182                                                                                                      CF_NIV_SUIV
# 19-141762                                                                                                     CF_NIV_SUIV
# 19-170952                                                                                                     CF_NIV_SUIV
# 19-174419                                                                                                     CF_NIV_SUIV
#
#                D_04_02_01_01_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Name  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                      NaN
# 18-55590                                                                                                                      NaN
# 18-78695                                                                                                                      NaN
# 19-109490                                                                                                                     NaN
# 19-109992                                                                                                                     NaN
# 11-116542                                                                                                                     NaN
# 21-37182                                                                                                                      NaN
# 19-141762                                                                                                                     NaN
# 19-170952                                                                                                                     NaN
# 19-174419                                                                                                                     NaN
#
#                D_04_02_01_02_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_DeclaredType  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                              NaN
# 18-55590                                                                                                                              NaN
# 18-78695                                                                                                                              NaN
# 19-109490                                                                                                                             NaN
# 19-109992                                                                                                                             NaN
# 11-116542                                                                                                                             NaN
# 21-37182                                                                                                                              NaN
# 19-141762                                                                                                                             NaN
# 19-170952                                                                                                                             NaN
# 19-174419                                                                                                                             NaN
#
#                D_04_02_01_03_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Scope  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                       NaN
# 18-55590                                                                                                                       NaN
# 18-78695                                                                                                                       NaN
# 19-109490                                                                                                                      NaN
# 19-109992                                                                                                                      NaN
# 11-116542                                                                                                                      NaN
# 21-37182                                                                                                                       NaN
# 19-141762                                                                                                                      NaN
# 19-170952                                                                                                                      NaN
# 19-174419                                                                                                                      NaN
#
#                D_04_02_01_04_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Value  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                       NaN
# 18-55590                                                                                                                       NaN
# 18-78695                                                                                                                       NaN
# 19-109490                                                                                                                      NaN
# 19-109992                                                                                                                      NaN
# 11-116542                                                                                                                      NaN
# 21-37182                                                                                                                       NaN
# 19-141762                                                                                                                      NaN
# 19-170952                                                                                                                      NaN
# 19-174419                                                                                                                      NaN
#
#                D_04_02_01_05_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_Nil  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                     NaN
# 18-55590                                                                                                                     NaN
# 18-78695                                                                                                                     NaN
# 19-109490                                                                                                                    NaN
# 19-109992                                                                                                                    NaN
# 11-116542                                                                                                                    NaN
# 21-37182                                                                                                                     NaN
# 19-141762                                                                                                                    NaN
# 19-170952                                                                                                                    NaN
# 19-174419                                                                                                                    NaN
#
#                 D_04_02_01_06_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_GlobalScope  \
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                            False
# 18-55590                                                                                                                            False
# 18-78695                                                                                                                            False
# 19-109490                                                                                                                           False
# 19-109992                                                                                                                           False
# 11-116542                                                                                                                           False
# 21-37182                                                                                                                            False
# 19-141762                                                                                                                           False
# 19-170952                                                                                                                           False
# 19-174419                                                                                                                           False
#
#                 D_04_02_01_07_Activiteprincipale_Entiteadjudicatrice_ProdtransdistribgazorELECTRICITEOrPROSPEXTRACTPETROLEGAZ_TypeSubstituted
# BOAMP_AVIS_NUM
# 17-23813                                                                                                                                False
# 18-55590                                                                                                                                False
# 18-78695                                                                                                                                False
# 19-109490                                                                                                                               False
# 19-109992                                                                                                                               False
# 11-116542                                                                                                                               False
# 21-37182                                                                                                                                False
# 19-141762                                                                                                                               False
# 19-170952                                                                                                                               False
# 19-174419                                                                                                                               False

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
