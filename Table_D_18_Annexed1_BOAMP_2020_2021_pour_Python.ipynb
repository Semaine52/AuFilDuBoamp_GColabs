# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_D_18_Annexed1_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table D_18_Annexed1 BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_18_annexed1.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_18_annexed1.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_18_annexed1.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_18' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_18' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 19-185152 to 20-153466
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   D_18_01_Annexed1_Infructueuxouverte       10 non-null     bool
#  1   D_18_02_Annexed1_Infructueuxrestreinte    10 non-null     bool
#  2   D_18_03_Annexed1_Recherche                10 non-null     bool
#  3   D_18_04_Annexed1_Raisonstechniques        10 non-null     bool
#  4   D_18_05_Annexed1_Raisonsartistiques       10 non-null     bool
#  5   D_18_06_Annexed1_Proprieteintellectuelle  10 non-null     bool
#  6   D_18_07_Annexed1_Urgenceimperieuse        10 non-null     bool
#  7   D_18_08_Annexed1_Marchecomplementaire     0 non-null      object
#  8   D_18_09_Annexed1_Prestationsidentiques    10 non-null     bool
#  9   D_18_10_Annexed1_Laureatsconcours         10 non-null     bool
#  10  D_18_11_Annexed1_Matierespremieres        0 non-null      float64
#  11  D_18_12_Annexed1_Cessationactivite        0 non-null      float64
#  12  D_18_13_Annexed1_Liquidateurs             0 non-null      float64
#  13  D_18_14_Annexed1_Horsscope                10 non-null     bool
#  14  D_18_15_Annexed1_Explication              10 non-null     object
# dtypes: bool(10), float64(3), object(2)
# memory usage: 580.0+ bytes

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                 D_18_01_Annexed1_Infructueuxouverte  \
# BOAMP_AVIS_NUM
# 19-185152                                     False
# 19-185761                                     False
# 19-185840                                     False
# 19-187356                                     False
# 19-190002                                     False
# 20-135955                                      True
# 20-144250                                      True
# 20-149778                                     False
# 20-152047                                     False
# 20-153466                                     False
#
#                 D_18_02_Annexed1_Infructueuxrestreinte  \
# BOAMP_AVIS_NUM
# 19-185152                                        False
# 19-185761                                        False
# 19-185840                                        False
# 19-187356                                        False
# 19-190002                                        False
# 20-135955                                        False
# 20-144250                                        False
# 20-149778                                        False
# 20-152047                                        False
# 20-153466                                        False
#
#                 D_18_03_Annexed1_Recherche  \
# BOAMP_AVIS_NUM
# 19-185152                            False
# 19-185761                             True
# 19-185840                             True
# 19-187356                            False
# 19-190002                            False
# 20-135955                            False
# 20-144250                            False
# 20-149778                            False
# 20-152047                            False
# 20-153466                            False
#
#                 D_18_04_Annexed1_Raisonstechniques  \
# BOAMP_AVIS_NUM
# 19-185152                                    False
# 19-185761                                    False
# 19-185840                                    False
# 19-187356                                    False
# 19-190002                                    False
# 20-135955                                    False
# 20-144250                                    False
# 20-149778                                    False
# 20-152047                                    False
# 20-153466                                    False
#
#                 D_18_05_Annexed1_Raisonsartistiques  \
# BOAMP_AVIS_NUM
# 19-185152                                     False
# 19-185761                                     False
# 19-185840                                     False
# 19-187356                                     False
# 19-190002                                     False
# 20-135955                                     False
# 20-144250                                     False
# 20-149778                                     False
# 20-152047                                     False
# 20-153466                                     False
#
#                 D_18_06_Annexed1_Proprieteintellectuelle  \
# BOAMP_AVIS_NUM
# 19-185152                                          False
# 19-185761                                          False
# 19-185840                                          False
# 19-187356                                           True
# 19-190002                                           True
# 20-135955                                          False
# 20-144250                                          False
# 20-149778                                           True
# 20-152047                                          False
# 20-153466                                          False
#
#                 D_18_07_Annexed1_Urgenceimperieuse  \
# BOAMP_AVIS_NUM
# 19-185152                                    False
# 19-185761                                    False
# 19-185840                                    False
# 19-187356                                    False
# 19-190002                                    False
# 20-135955                                    False
# 20-144250                                    False
# 20-149778                                    False
# 20-152047                                    False
# 20-153466                                    False
#
#                D_18_08_Annexed1_Marchecomplementaire  \
# BOAMP_AVIS_NUM
# 19-185152                                        NaN
# 19-185761                                        NaN
# 19-185840                                        NaN
# 19-187356                                        NaN
# 19-190002                                        NaN
# 20-135955                                        NaN
# 20-144250                                        NaN
# 20-149778                                        NaN
# 20-152047                                        NaN
# 20-153466                                        NaN
#
#                 D_18_09_Annexed1_Prestationsidentiques  \
# BOAMP_AVIS_NUM
# 19-185152                                        False
# 19-185761                                        False
# 19-185840                                        False
# 19-187356                                        False
# 19-190002                                        False
# 20-135955                                        False
# 20-144250                                        False
# 20-149778                                        False
# 20-152047                                        False
# 20-153466                                        False
#
#                 D_18_10_Annexed1_Laureatsconcours  \
# BOAMP_AVIS_NUM
# 19-185152                                    True
# 19-185761                                   False
# 19-185840                                   False
# 19-187356                                   False
# 19-190002                                   False
# 20-135955                                   False
# 20-144250                                   False
# 20-149778                                   False
# 20-152047                                   False
# 20-153466                                   False
#
#                 D_18_11_Annexed1_Matierespremieres  \
# BOAMP_AVIS_NUM
# 19-185152                                      NaN
# 19-185761                                      NaN
# 19-185840                                      NaN
# 19-187356                                      NaN
# 19-190002                                      NaN
# 20-135955                                      NaN
# 20-144250                                      NaN
# 20-149778                                      NaN
# 20-152047                                      NaN
# 20-153466                                      NaN
#
#                 D_18_12_Annexed1_Cessationactivite  \
# BOAMP_AVIS_NUM
# 19-185152                                      NaN
# 19-185761                                      NaN
# 19-185840                                      NaN
# 19-187356                                      NaN
# 19-190002                                      NaN
# 20-135955                                      NaN
# 20-144250                                      NaN
# 20-149778                                      NaN
# 20-152047                                      NaN
# 20-153466                                      NaN
#
#                 D_18_13_Annexed1_Liquidateurs  D_18_14_Annexed1_Horsscope  \
# BOAMP_AVIS_NUM
# 19-185152                                 NaN                       False
# 19-185761                                 NaN                       False
# 19-185840                                 NaN                       False
# 19-187356                                 NaN                       False
# 19-190002                                 NaN                       False
# 20-135955                                 NaN                       False
# 20-144250                                 NaN                       False
# 20-149778                                 NaN                       False
# 20-152047                                 NaN                        True
# 20-153466                                 NaN                        True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 D_18_15_Annexed1_Explication
# BOAMP_AVIS_NUM
# 19-185152                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Il s'agit d'un marché négocié faisant suite à un concours, en application de l'article 30.I.6 du Décret no2016-360 du 25 mars 2016 relatif aux marchés marchés publics.
# 19-185761                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Recours à l'article 2122-10 du code de la commande publique.Les prototypes à réaliser sont 2 machines très complexes utilisant des briques technologiques à létat de lart. Les spécifications visées par le projet Flexiburst nexistent pas dans le commerce.Ces prototypes de TRL faibles ne peuvent en aucun cas être commercialisés.
# 19-185840                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Recours à l'article 2122-10 du code de la commande publique. Les prototypes à réaliser sont 2 machines très complexes utilisant des briques technologiques à létat de lart. Les spécifications visées par le projet Flexiburst nexistent pas dans le commerce. Ces prototypes de TRL faibles ne peuvent en aucun cas être commercialisés.
# 19-187356       En application des dispositions de larticle R2122-3 du Code de la commande publique, un marché peut être passé sans publicité ni mise en concurrence préalables lorsque les fournitures ne peuvent être fournies que par un opérateur économique déterminé en raison de l'existence de droits d'exclusivité, notamment de droits de propriété intellectuelle.The MathWorks SAS filiale de The MathWorks, Inc., seul distributeur du logiciel MATLAB et de ses services connexes, à savoir la maintenance, le support, le conseil, la formation et toute activité liée ou accessoire à ce qui précède en France, est la seule société à même de satisfaire les besoins de Sorbonne Université.Par conséquent, ce marché public ne pourra être attribué, en raison de lexistence de droits dexclusivité et notamment des droits de propriété intellectuelle, quau seul prestataire précédemment identifié.
# 19-190002                                                                                                                                                                                                                                                                                                                                                                                  La société Sas Institute a produit une attestation d'exclusivité attestant qu'elle détient lintégralité des droits dauteur, moraux et patrimoniaux, sur les progiciels SAS.De plus, la société précise quelle na concédé à aucun autre opérateur économique que sa filiale française de droits permettant de commercialiser et de distibuer les progiciels ainsi que dagir sur ces Progiciels, notamment par des opérations de mise à jour, dadaptation, de maintenance et de support technique sur le territoire français.
# 20-135955                                                                                                                                                                                                                                                                                                                                                                                                                                                              Par avis no3422294, la Métropole Aix-Marseille Provence a lancé le 15/03/2019, un appel d'offres relatif à la réalisation dun pôle déchanges multimodal à Martigues comportant 8 lots.Le lot 2 a été déclaré infructueux en raison de labsence de pli. Conformément à l'article R. 2122-2 du code de la commande publique, il a été décidé de relancer la consultation sous la forme dun marché sans publicité ni mise en concurrence préalables.
# 20-144250                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Ce marché lancé en procédure négociée sans publicité ni mise en concurrence préalable en application des dispositions de l'art. R2122-2 du code de la commande publique
# 20-149778                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Traitement par photo-stimulation sur une zone anatomique étendue.
# 20-152047                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Marché passé en procédure adaptée
# 20-153466                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        La société est le propriétaire exclusif du progiciel " IRIS FORM " et quà ce titre la société est seule habilitée à fournir la prestation.

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
