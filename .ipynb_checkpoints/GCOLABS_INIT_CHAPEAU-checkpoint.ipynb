# %% [markdown]
# LICENCE ETALAB 2.0
#
# Données originales en open data recueillies sur https://www.data.gouv.fr/fr/datasets/api-boamp-beta/
#
# Le dépôt cloné ici depuis GitHub est à l'adresse https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV
# ### Voir aussi:
# https://www.boamp.fr
#
# https://www.data.gouv.fr/fr/datasets/boamp/
#
# ### et https://aufilduboamp.com
