# %% [markdown]
# ► <a style="color:red; font-size:20px;" alt="Lien vers la dernière mouture de ce chapeau en plein écran"  target=_blank href="https://www.aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html">Lien vers la dernière mouture de ce chapeau en plein écran.</a>
#
# # AuFilDuBoamp, ou de l'Open Data du Bulletin officiel des annonces des marchés publics (BOAMP) avec Python
# __Un projet Semaine52.__
#
# __Par Jean-Marie FALVET, organisateur à Aix-en-Provence.__
#
#
#
# <img src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/JMF_LOGO_aufilduboamp2.png" alt="Logo AuFilDuBoamp"
#      width="100" height="100"><img width="200" height="200" src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/licence-ouverte-open-licence.gif">
#
#
# Licence etalab 2.0 ► <a target=_blank href="https://www.etalab.gouv.fr/wp-content/uploads/2017/04/ETALAB-Licence-Ouverte-v2.0.pdf">En savoir plus (pdf)</a>
#
# En cour de rédaction...
#
# ## Entrées principales:
#
#
# | __Table BOAMP__|__Lien vers son notebook découverte Google Colab__|__Lien vers sa rubrique dédiée sur AuFilDuBoamp.com__|
# |---------------|---------------------|---------------------|
# |D_01_Identite| <a target=_blank href="https://colab.research.google.com/drive/1GNdYgs5cp7wYi5X9iJgnZ9NmfYOTdVQe?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>|<a target=_blank href="https://aufilduboamp.com/rubrique41.html">Ouvrir la rubrique dans un nouvel onglet</a>"|
# |D_02_Typeorganisme| <a target=_blank href="https://colab.research.google.com/drive/1mQ6J0qarf4W05tpvKZkMoNHqWicBrhYR?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique42.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_03_Typepouvoiradjudicateur| <a target=_blank href="https://colab.research.google.com/drive/1kj1E4WSs6Vr3wzlG0BuHPgZOK6fwRmnR?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique43.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_04_Activiteprincipale| <a target=_blank href="https://colab.research.google.com/drive/1Yp9QMiwwUGmZrBGF49ek-yAh8XXu2wDf?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique44.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_05_Objet| <a target=_blank href="https://colab.research.google.com/drive/12D2vjY7txNBmxLHcjTFKiYlHrew85JOU?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique45.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_06_Procedure| <a target=_blank href="https://colab.research.google.com/drive/1uR6IyrayZ20cjp-K4cj6JhNx9_Pqy6Gd?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique46.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_07_Publicationanterieure| <a target=_blank href="https://colab.research.google.com/drive/1U1FeRdYoFfcekwjnn1nBCZltT_yb8gWm?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique47.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_08_Attribution| <a target=_blank href="https://colab.research.google.com/drive/1QVfJn-Gqfgw_fA-Ry_yk8SRPyXKRcQdv?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique48.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_09_Rectif|<a target=_blank href="https://colab.research.google.com/drive/1ELl_GoMWKJTzVLJuPHZgPDiYvp365_Vk?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique49.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_10_Annulation| <a target=_blank href="https://colab.research.google.com/drive/1pTdZLV0B5_LmimssQ5OC-d__WwH8c3kp?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique50.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_11_Conditiondelai| <a target=_blank href="https://colab.research.google.com/drive/1U9hh9YUVAw97hpT-s3b9HfYJGod3lIfM?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique51.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_12_Conditionrelativemarche| <a target=_blank href="https://colab.research.google.com/drive/1Z7dKh8SieUKcQbMQKbSOvYwl01ogTynd?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>|<a target=_blank href="https://aufilduboamp.com/rubrique52.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_13_Conditionparticipation| <a target=_blank href="https://colab.research.google.com/drive/19WduD4gDmyQncl01OMimBwHR5zFpFMMc?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique53.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_14_Conditionparticipationsystmequalif| <a target=_blank href="https://colab.research.google.com/drive/1mt0f9MJYB8vTNaM04kUPPzY1QDQ2wRNk?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>|<a target=_blank href="https://aufilduboamp.com/rubrique54.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_15_Conditionadministrative| <a target=_blank href="https://colab.research.google.com/drive/1cQd1uQVfxAja-vN3G-Tz0ktoy1Gtbs-L?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique55.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_16_Renseignementscomplementaires| <a target=_blank href="https://colab.research.google.com/drive/1bpHiEMabGVO5rO41Ro3BKpA6j7vZb_4u?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique56.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_17_Modif| <a target=_blank href="https://colab.research.google.com/drive/1NSBXfy8ahmkEWuJw46z282oXXzCwHyip?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique57.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_18_Annexed1|<a target=_blank href="https://colab.research.google.com/drive/1MTHm0fmeUCRoNecXTAXowwwTxzC4OvAs?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique58.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_19_Annexed2| <a target=_blank href="https://colab.research.google.com/drive/16ZlxpJzoZTZ1tPgvylhDdkzjG5DGvGP6?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique59.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_20_Annexed3| <a target=_blank href="https://colab.research.google.com/drive/1N2YC-L_Ubz2meYF_C9BbyYPYGqpU2pQ0?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique60.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |D_21_Annexed4| <a target=_blank href="https://colab.research.google.com/drive/1f1UC6C7uXELVaZ83KjaM2PW947OMq398?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique61.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |G_01_Reference| <a target=_blank href="https://colab.research.google.com/drive/1bAR9g_guT8ZmnwtGrwuI3re0bLX-2uw_?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique62.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |G_02_Marche| <a target=_blank href="https://colab.research.google.com/drive/1FWxBwyM_jY6SHs69IzwiFZq4-V2-HWtW?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique63.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |G_03_Nomhtml| <a target=_blank href="https://colab.research.google.com/drive/1iluwVaydq-gypOsXhXwfbwilJX64kWOn?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique64.html">Ouvrir la rubrique dans un nouvel onglet</a>|
# |G_04_Indexation| <a target=_blank href="https://colab.research.google.com/drive/1xoxre7BrAUn9Dt4AgLxYROobE_neQhXw?usp=sharing">Ouvrir ce Notebook sur Google Colab dans un nouvel onglet</a>| <a target=_blank href="https://aufilduboamp.com/rubrique65.html">Ouvrir la rubrique dans un nouvel onglet</a>|
#
# ### Semaine52/AuFilDuBoamp ailleurs en ligne:
# - <a target=_blank href="https://www.AuFilDuBoamp.com">AuFilDuBoamp.com</a>
# - <a target=_blank href="https://twitter.com/AuFilDuBoamp">Rejoindre AuFilDuBoamp sur Twitter</a>
# - <a target=_blank href="https://github.com/Semaine52">Rejoindre Semaine52/AuFilDuBoamp sur GitHub</a>
# - <a target=_blank href="https://www.data.gouv.fr/fr/organizations/aufilduboamp/">Rejoindre Semaine52/AuFilDuBoamp sur DataGouv.fr</a>
# - <a target=_blank href="https://teamopendata.org/u/semaine52_jmf/summary">Rejoindre Semaine52/AuFilDuBoamp sur TeamOpenData</a>
# - <a target=_blank href="https://nbviewer.jupyter.org/github/Semaine52/AuFilDuBoamp_Lab/blob/master/notebooks/_Sommaire.ipynb">Un tour d'horizon complémentaire des tables sur NBViewer</a>
# - <a target=_blank href="https://www.Semaine52.com/">Voir aussi Semaine52.com pour une veille Twitter des institutions et des ambassades</a>
# - Courriel -> aufilduboamp@gmail.com</a>
#
# ### Origine des données/imports:
# - Données originales en open data recueillies sur DataGouv.fr <a target=_blank href="https://www.data.gouv.fr/fr/datasets/api-boamp-beta/">Cliquer ici</a>
# - Le dépôt cloné ici depuis GitHub est à l'adresse <a target=_blank href="https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV">Cliquer ici</a>
#
# ### Voir aussi le site officiel du Bulletin officiel des annonces des marchés publics:
# - <a target=_blank href="https://www.boamp.fr">boamp.fr</a>
#
# ### et enfin le Code des marchés publics:
# - <a target=_blank href="https://www.legifrance.gouv.fr/codes/id/LEGITEXT000037701019/">Légifrance</a>
#
# ----
