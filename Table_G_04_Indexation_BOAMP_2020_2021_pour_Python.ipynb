# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_GColabs/blob/main/Table_G_04_Indexation_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table G_04_Indexation BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_g_04_indexation.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_g_04_indexation.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_g_04_indexation.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Ceci est un Notebook Jupyter avec du Python dedans

## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# Cloning into 'AuFilDuBoamp_Outils_CSV'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 97 (delta 51), reused 82 (delta 41), pack-reused 0
# Unpacking objects: 100% (97/97), done.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'G_04' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'G_04' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2828: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2828: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 07-127994 to 19-140862
# Data columns (total 17 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   G_04_01_Indexation_Datepublication                         10 non-null     object
#  1   G_04_02_Indexation_Datelimitereponse                       5 non-null      object
#  2   G_04_03_Indexation_Datefindiffusion                        10 non-null     object
#  3   G_04_04_Indexation_Classes                                 10 non-null     object
#  4   G_04_04_01_Indexation_Classes_Classe                       10 non-null     object
#  5   G_04_04_01_01_Indexation_Classes_Classe_Code               0 non-null      float64
#  6   G_04_04_01_02_Indexation_Classes_Classe_Libelle            0 non-null      object
#  7   G_04_05_Indexation_Descripteurs                            10 non-null     object
#  8   G_04_05_01_Indexation_Descripteurs_Descripteur             10 non-null     object
#  9   G_04_05_01_01_Indexation_Descripteurs_Descripteur_Code     10 non-null     int64
#  10  G_04_05_01_02_Indexation_Descripteurs_Descripteur_Libelle  10 non-null     object
#  11  G_04_06_Indexation_Criteressociauxenv                      10 non-null     object
#  12  G_04_06_01_Indexation_Criteressociauxenv_Sociaux           10 non-null     bool
#  13  G_04_06_02_Indexation_Criteressociauxenv_Environnementaux  10 non-null     bool
#  14  G_04_07_Indexation_Deppublication                          10 non-null     object
#  15  G_04_08_Indexation_Depprestation                           0 non-null      object
#  16  G_04_09_Indexation_Resumeobjet                             10 non-null     object
# dtypes: bool(2), float64(1), int64(1), object(13)
# memory usage: 1.3+ KB

# %% [markdown]
# ### df.head()

# %%
# CONSULTER LES PREMIÈRES LIGNES DE DF
df.head(10)
# Out:
#                G_04_01_Indexation_Datepublication  \
# BOAMP_AVIS_NUM
# 07-127994                     2020-01-19 23:00:00
# 07-127994                     2020-01-19 23:00:00
# 17-23813                      2020-01-30 23:00:00
# 17-31705                      2020-01-28 23:00:00
# 18-55590                      2020-01-17 23:00:00
# 11-116542                     2021-01-18 00:00:00
# 21-37182                      2021-03-21 00:00:00
# 19-140862                     2021-01-20 00:00:00
# 19-140862                     2021-01-20 00:00:00
# 19-140862                     2021-01-20 00:00:00
#
#                G_04_02_Indexation_Datelimitereponse  \
# BOAMP_AVIS_NUM
# 07-127994                       2020-02-20 11:00:00
# 07-127994                       2020-02-20 11:00:00
# 17-23813                                        NaN
# 17-31705                        2020-03-02 10:00:00
# 18-55590                        2020-02-18 16:00:00
# 11-116542                       2021-02-08 12:00:00
# 21-37182                                        NaN
# 19-140862                                       NaN
# 19-140862                                       NaN
# 19-140862                                       NaN
#
#                G_04_03_Indexation_Datefindiffusion G_04_04_Indexation_Classes  \
# BOAMP_AVIS_NUM
# 07-127994                      2020-02-19 23:00:00                CF_NIV_SUIV
# 07-127994                      2020-02-19 23:00:00                CF_NIV_SUIV
# 17-23813                       2020-03-18 23:00:00                CF_NIV_SUIV
# 17-31705                       2020-03-01 23:00:00                CF_NIV_SUIV
# 18-55590                       2020-02-17 23:00:00                CF_NIV_SUIV
# 11-116542                      2021-02-08 00:00:00                CF_NIV_SUIV
# 21-37182                       2021-05-18 23:00:00                CF_NIV_SUIV
# 19-140862                      2021-12-31 00:00:00                CF_NIV_SUIV
# 19-140862                      2021-12-31 00:00:00                CF_NIV_SUIV
# 19-140862                      2021-12-31 00:00:00                CF_NIV_SUIV
#
#                G_04_04_01_Indexation_Classes_Classe  \
# BOAMP_AVIS_NUM
# 07-127994                               CF_NIV_SUIV
# 07-127994                               CF_NIV_SUIV
# 17-23813                                CF_NIV_SUIV
# 17-31705                                CF_NIV_SUIV
# 18-55590                                CF_NIV_SUIV
# 11-116542                               CF_NIV_SUIV
# 21-37182                                CF_NIV_SUIV
# 19-140862                               CF_NIV_SUIV
# 19-140862                               CF_NIV_SUIV
# 19-140862                               CF_NIV_SUIV
#
#                 G_04_04_01_01_Indexation_Classes_Classe_Code  \
# BOAMP_AVIS_NUM
# 07-127994                                                NaN
# 07-127994                                                NaN
# 17-23813                                                 NaN
# 17-31705                                                 NaN
# 18-55590                                                 NaN
# 11-116542                                                NaN
# 21-37182                                                 NaN
# 19-140862                                                NaN
# 19-140862                                                NaN
# 19-140862                                                NaN
#
#                G_04_04_01_02_Indexation_Classes_Classe_Libelle  \
# BOAMP_AVIS_NUM
# 07-127994                                                  NaN
# 07-127994                                                  NaN
# 17-23813                                                   NaN
# 17-31705                                                   NaN
# 18-55590                                                   NaN
# 11-116542                                                  NaN
# 21-37182                                                   NaN
# 19-140862                                                  NaN
# 19-140862                                                  NaN
# 19-140862                                                  NaN
#
#                G_04_05_Indexation_Descripteurs  \
# BOAMP_AVIS_NUM
# 07-127994                          CF_NIV_SUIV
# 07-127994                          CF_NIV_SUIV
# 17-23813                           CF_NIV_SUIV
# 17-31705                           CF_NIV_SUIV
# 18-55590                           CF_NIV_SUIV
# 11-116542                          CF_NIV_SUIV
# 21-37182                           CF_NIV_SUIV
# 19-140862                          CF_NIV_SUIV
# 19-140862                          CF_NIV_SUIV
# 19-140862                          CF_NIV_SUIV
#
#                G_04_05_01_Indexation_Descripteurs_Descripteur  \
# BOAMP_AVIS_NUM
# 07-127994                                         CF_NIV_SUIV
# 07-127994                                         CF_NIV_SUIV
# 17-23813                                          CF_NIV_SUIV
# 17-31705                                          CF_NIV_SUIV
# 18-55590                                          CF_NIV_SUIV
# 11-116542                                         CF_NIV_SUIV
# 21-37182                                          CF_NIV_SUIV
# 19-140862                                         CF_NIV_SUIV
# 19-140862                                         CF_NIV_SUIV
# 19-140862                                         CF_NIV_SUIV
#
#                 G_04_05_01_01_Indexation_Descripteurs_Descripteur_Code  \
# BOAMP_AVIS_NUM
# 07-127994                                                           38
# 07-127994                                                          405
# 17-23813                                                           197
# 17-31705                                                            66
# 18-55590                                                            17
# 11-116542                                                           59
# 21-37182                                                            34
# 19-140862                                                           33
# 19-140862                                                           57
# 19-140862                                                           62
#
#                G_04_05_01_02_Indexation_Descripteurs_Descripteur_Libelle  \
# BOAMP_AVIS_NUM
# 07-127994                                                           Bois
# 07-127994                                     Déchetterie (exploitation)
# 17-23813                                               Maîtrise d'oeuvre
# 17-31705                                         Restauration collective
# 18-55590                                                       Ascenseur
# 11-116542                            Chauffage (exploitation, entretien)
# 21-37182                                                           Benne
# 19-140862                                                       Bâtiment
# 19-140862                                                      Charpente
# 19-140862                                                  Climatisation
#
#                G_04_06_Indexation_Criteressociauxenv  \
# BOAMP_AVIS_NUM
# 07-127994                                CF_NIV_SUIV
# 07-127994                                CF_NIV_SUIV
# 17-23813                                 CF_NIV_SUIV
# 17-31705                                 CF_NIV_SUIV
# 18-55590                                 CF_NIV_SUIV
# 11-116542                                CF_NIV_SUIV
# 21-37182                                 CF_NIV_SUIV
# 19-140862                                CF_NIV_SUIV
# 19-140862                                CF_NIV_SUIV
# 19-140862                                CF_NIV_SUIV
#
#                 G_04_06_01_Indexation_Criteressociauxenv_Sociaux  \
# BOAMP_AVIS_NUM
# 07-127994                                                  False
# 07-127994                                                  False
# 17-23813                                                    True
# 17-31705                                                   False
# 18-55590                                                   False
# 11-116542                                                  False
# 21-37182                                                   False
# 19-140862                                                  False
# 19-140862                                                  False
# 19-140862                                                  False
#
#                 G_04_06_02_Indexation_Criteressociauxenv_Environnementaux  \
# BOAMP_AVIS_NUM
# 07-127994                                                           False
# 07-127994                                                           False
# 17-23813                                                            False
# 17-31705                                                            False
# 18-55590                                                            False
# 11-116542                                                           False
# 21-37182                                                            False
# 19-140862                                                           False
# 19-140862                                                           False
# 19-140862                                                           False
#
#                G_04_07_Indexation_Deppublication  \
# BOAMP_AVIS_NUM
# 07-127994                                     67
# 07-127994                                     67
# 17-23813                                      94
# 17-31705                                     20B
# 18-55590                                       7
# 11-116542                                     60
# 21-37182                                      13
# 19-140862                                    974
# 19-140862                                    974
# 19-140862                                    974
#
#                G_04_08_Indexation_Depprestation  \
# BOAMP_AVIS_NUM
# 07-127994                                   NaN
# 07-127994                                   NaN
# 17-23813                                    NaN
# 17-31705                                    NaN
# 18-55590                                    NaN
# 11-116542                                   NaN
# 21-37182                                    NaN
# 19-140862                                   NaN
# 19-140862                                   NaN
# 19-140862                                   NaN
#
#                                                                                                                                           G_04_09_Indexation_Resumeobjet
# BOAMP_AVIS_NUM
# 07-127994       traitement du bois déposé par les habitants de la communauté de communes du kochersberg dans les déchetteries de dossenheim-kochersberg et pfulgriesheim
# 07-127994       traitement du bois déposé par les habitants de la communauté de communes du kochersberg dans les déchetteries de dossenheim-kochersberg et pfulgriesheim
# 17-23813                                                                                                                maîtrise d'oeuvre - logements sociaux mont mesly
# 17-31705                                                                                fourniture et livraison de repas pour la restauration scolaire en liaison froide
# 18-55590                                                                                                           réhabilitation et extension d'un bâtiment à davézieux
# 11-116542                                                                  entretien des chaufferies, radians, aérothermes et adoucisseurs d'eau des bâtiments communaux
# 21-37182                                                   Fourniture de bennes de collecte de déchets d'une catégorie de 12 m3 pour la Métropole Aix Marseille Provence
# 19-140862                                                                             construction d'une gare routière sur la commune du tampon - modification de marché
# 19-140862                                                                             construction d'une gare routière sur la commune du tampon - modification de marché
# 19-140862                                                                             construction d'une gare routière sur la commune du tampon - modification de marché

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
